# %%
from bs4 import BeautifulSoup as bs
import requests as re
import pandas as pd
import numpy as np
con = re.get('https://www.google.com/finance/markets/gainers?authuser=0').text
soup = bs(con,'lxml')
box = soup.find_all("li")
ticket=[]
name = []
price = []
increase = []
pseincre = []
for i in box:
    ticket.append(i.find("div" , class_="COaKTb").text)
    name.append(i.find("div" , class_="ZvmM7").text)
    price.append(i.find("div" , class_="YMlKec").text)
    increase.append(i.find("span" , class_="P2Luy Ez2Ioe").text)
    pseincre.append(i.find("div" , class_="JwB6zf").text)
df = pd.DataFrame({"ticket" : ticket,"name" : name , "price" : price , "increase" : increase , "pseincre" : pseincre})

# %%
df.to_csv('2023-12-11_google_finance.csv')

# %%
df.head(5)
# Out:
#       ticket                                    name    price increase  \
# 0      ARVEE          Arvee Laboratories (India) Ltd  ₹190.20  +₹31.70
# 1   BAGFILMS              B.A.G. Films and Media Ltd    ₹8.40   +₹1.40
# 2      IREDA  Indian Renewable Energy Dev Agency Ltd   ₹85.00  +₹14.15
# 3  ENERGYDEV          Energy Development Company Ltd   ₹26.15   +₹4.35
# 4    CALSOFT         California Software Company Ltd   ₹18.40   +₹3.05
#
#   pseincre
# 0   20.00%
# 1   20.00%
# 2   19.97%
# 3   19.95%
# 4   19.87%

# %%
df.shape
# Out:
# (50, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ticket    50 non-null     object
#  1   name      50 non-null     object
#  2   price     50 non-null     object
#  3   increase  50 non-null     object
#  4   pseincre  50 non-null     object
# dtypes: object(5)
# memory usage: 2.1+ KB

# %%
df.head(5)
# Out:
#       ticket                                    name    price increase  \
# 0      ARVEE          Arvee Laboratories (India) Ltd  ₹190.20  +₹31.70
# 1   BAGFILMS              B.A.G. Films and Media Ltd    ₹8.40   +₹1.40
# 2      IREDA  Indian Renewable Energy Dev Agency Ltd   ₹85.00  +₹14.15
# 3  ENERGYDEV          Energy Development Company Ltd   ₹26.15   +₹4.35
# 4    CALSOFT         California Software Company Ltd   ₹18.40   +₹3.05
#
#   pseincre
# 0   20.00%
# 1   20.00%
# 2   19.97%
# 3   19.95%
# 4   19.87%

# %%
df['price']=df['price'].str.split("₹").str[1]

# %%
df['increase']=df['increase'].str.split("₹").str[1]

# %%
df['pseincre']=df['pseincre'].str.split("%").str[0]

# %%
df.head()
# Out:
#       ticket                                    name   price increase pseincre
# 0      ARVEE          Arvee Laboratories (India) Ltd  190.20    31.70    20.00
# 1   BAGFILMS              B.A.G. Films and Media Ltd    8.40     1.40    20.00
# 2      IREDA  Indian Renewable Energy Dev Agency Ltd   85.00    14.15    19.97
# 3  ENERGYDEV          Energy Development Company Ltd   26.15     4.35    19.95
# 4    CALSOFT         California Software Company Ltd   18.40     3.05    19.87

# %%
df['price']=df['price'].replace(",","")

# %%
df['price']=df['price'].str.replace(",","")

# %%
df['price']=df['price'].astype(float)

# %%
df.head(5)
# Out:
#       ticket                                    name   price increase pseincre
# 0      ARVEE          Arvee Laboratories (India) Ltd  190.20    31.70    20.00
# 1   BAGFILMS              B.A.G. Films and Media Ltd    8.40     1.40    20.00
# 2      IREDA  Indian Renewable Energy Dev Agency Ltd   85.00    14.15    19.97
# 3  ENERGYDEV          Energy Development Company Ltd   26.15     4.35    19.95
# 4    CALSOFT         California Software Company Ltd   18.40     3.05    19.87

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ticket    50 non-null     object
#  1   name      50 non-null     object
#  2   price     50 non-null     float64
#  3   increase  50 non-null     object
#  4   pseincre  50 non-null     object
# dtypes: float64(1), object(4)
# memory usage: 2.1+ KB

# %%
df['increase']=df['increase'].astype(float)

# %%
df['pseincre']=df['pseincre'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ticket    50 non-null     object
#  1   name      50 non-null     object
#  2   price     50 non-null     float64
#  3   increase  50 non-null     float64
#  4   pseincre  50 non-null     float64
# dtypes: float64(3), object(2)
# memory usage: 2.1+ KB

# %%
df.head()
# Out:
#       ticket                                    name   price  increase  \
# 0      ARVEE          Arvee Laboratories (India) Ltd  190.20     31.70
# 1   BAGFILMS              B.A.G. Films and Media Ltd    8.40      1.40
# 2      IREDA  Indian Renewable Energy Dev Agency Ltd   85.00     14.15
# 3  ENERGYDEV          Energy Development Company Ltd   26.15      4.35
# 4    CALSOFT         California Software Company Ltd   18.40      3.05
#
#    pseincre
# 0     20.00
# 1     20.00
# 2     19.97
# 3     19.95
# 4     19.87

# %%
df.sort_values('price',ascending=False)
# Out:
#         ticket                                      name    price  increase  \
# 16     SANDUMA        Sandur Manganese and Iron Ores Ltd  2138.80    217.90
# 13     CHEVIOT                      Cheviot Company Ltd.  1435.75    167.30
# 42    KPIGREEN                      KPI Green Energy Ltd  1212.65     65.45
# 26      NETWEB             Netweb Technologies India Ltd  1083.00     88.00
# 40  CENTURYPLY             Century Plyboards (India) Ltd   729.00     42.15
# 33    STEELCAS                             Steelcast Ltd   624.85     44.90
# 30   MANGLMCEM                       Mangalam Cement Ltd   543.20     40.60
# 41        STAR                Strides Pharma Science Ltd   542.85     30.60
# 15      SUBROS                                Subros Ltd   503.50     53.15
# 27    INOXWIND                             Inox Wind Ltd   394.40     31.05
# 34  NRBBEARING                      NRB Bearings Limited   303.50     21.75
# ...

# %%
df.sort_values('increase',ascending=False)
# Out:
#         ticket                                      name    price  increase  \
# 16     SANDUMA        Sandur Manganese and Iron Ores Ltd  2138.80    217.90
# 13     CHEVIOT                      Cheviot Company Ltd.  1435.75    167.30
# 26      NETWEB             Netweb Technologies India Ltd  1083.00     88.00
# 42    KPIGREEN                      KPI Green Energy Ltd  1212.65     65.45
# 15      SUBROS                                Subros Ltd   503.50     53.15
# 33    STEELCAS                             Steelcast Ltd   624.85     44.90
# 40  CENTURYPLY             Century Plyboards (India) Ltd   729.00     42.15
# 30   MANGLMCEM                       Mangalam Cement Ltd   543.20     40.60
# 0        ARVEE            Arvee Laboratories (India) Ltd   190.20     31.70
# 27    INOXWIND                             Inox Wind Ltd   394.40     31.05
# 41        STAR                Strides Pharma Science Ltd   542.85     30.60
# ...

# %%
df['increase_ratio']=df['price']/df['increase']

# %%
df['increase_ratio']=df['increase_ratio'].round(2)

# %%
df
# Out:
#         ticket                                      name    price  increase  \
# 0        ARVEE            Arvee Laboratories (India) Ltd   190.20     31.70
# 1     BAGFILMS                B.A.G. Films and Media Ltd     8.40      1.40
# 2        IREDA    Indian Renewable Energy Dev Agency Ltd    85.00     14.15
# 3    ENERGYDEV            Energy Development Company Ltd    26.15      4.35
# 4      CALSOFT           California Software Company Ltd    18.40      3.05
# 5      FCSSOFT                FCS Software Solutions Ltd     4.55      0.75
# 6      SHRENIK                               Shrenik Ltd     1.30      0.20
# 7      VIVIDHA                       Visagar Polytex Ltd     1.05      0.15
# 8   NILASPACES                           Nila Spaces Ltd     4.95      0.70
# 9    BHAGYANGR                     Bhagyanagar India Ltd    84.00     10.35
# 10        BRNL                   Bharat Road Network Ltd    47.60      5.75
# ...

# %%
df.sort_values('increase_ratio',ascending=False).head(10)
# Out:
#         ticket                                      name    price  increase  \
# 49  AMBICAAGAR   Ambica Agarbathies Aroma&Industries Ltd    31.70      1.60
# 48       ANMOL                           Anmol India Ltd    64.35      3.25
# 47  SHREEPUSHK  Shree Pushkar Chemicals & Fertilisrs Ltd   207.15     10.50
# 46      MITTAL                     Mittal Life Style Ltd     1.95      0.10
# 45     GANDHAR          Gandhar Oil Refinery (INDIA) Ltd   287.10     15.00
# 44    IMAGICAA           Imagicaaworld Entertainment Ltd    57.85      3.10
# 43       BSHSL             Bombay Super Hybrid Seeds Ltd   273.50     14.70
# 42    KPIGREEN                      KPI Green Energy Ltd  1212.65     65.45
# 41        STAR                Strides Pharma Science Ltd   542.85     30.60
# 40  CENTURYPLY             Century Plyboards (India) Ltd   729.00     42.15
#
#     pseincre  increase_ratio
# 49      5.32           19.81
# 48      5.32           19.80
# 47      5.34           19.73
# ...

# %%
a=df.sort_values('increase_ratio',ascending=False)

# %%
m=a[(a['price']>200)==True]

# %%
n=df[(df.sort_values('increase_ratio',ascending=False)['price']>200)==True]
# Out:
# C:\Users\aviji\AppData\Local\Temp\ipykernel_10532\1799271130.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   n=df[(df.sort_values('increase_ratio',ascending=False)['price']>200)==True]

# %%
m.shape
# Out:
# (14, 6)

# %%
n.shape
# Out:
# (14, 6)

# %%
m
# Out:
#         ticket                                      name    price  increase  \
# 47  SHREEPUSHK  Shree Pushkar Chemicals & Fertilisrs Ltd   207.15     10.50
# 45     GANDHAR          Gandhar Oil Refinery (INDIA) Ltd   287.10     15.00
# 43       BSHSL             Bombay Super Hybrid Seeds Ltd   273.50     14.70
# 42    KPIGREEN                      KPI Green Energy Ltd  1212.65     65.45
# 41        STAR                Strides Pharma Science Ltd   542.85     30.60
# 40  CENTURYPLY             Century Plyboards (India) Ltd   729.00     42.15
# 34  NRBBEARING                      NRB Bearings Limited   303.50     21.75
# 33    STEELCAS                             Steelcast Ltd   624.85     44.90
# 30   MANGLMCEM                       Mangalam Cement Ltd   543.20     40.60
# 27    INOXWIND                             Inox Wind Ltd   394.40     31.05
# 26      NETWEB             Netweb Technologies India Ltd  1083.00     88.00
# ...

# %%
n
# Out:
#         ticket                                      name    price  increase  \
# 13     CHEVIOT                      Cheviot Company Ltd.  1435.75    167.30
# 15      SUBROS                                Subros Ltd   503.50     53.15
# 16     SANDUMA        Sandur Manganese and Iron Ores Ltd  2138.80    217.90
# 26      NETWEB             Netweb Technologies India Ltd  1083.00     88.00
# 27    INOXWIND                             Inox Wind Ltd   394.40     31.05
# 30   MANGLMCEM                       Mangalam Cement Ltd   543.20     40.60
# 33    STEELCAS                             Steelcast Ltd   624.85     44.90
# 34  NRBBEARING                      NRB Bearings Limited   303.50     21.75
# 40  CENTURYPLY             Century Plyboards (India) Ltd   729.00     42.15
# 41        STAR                Strides Pharma Science Ltd   542.85     30.60
# 42    KPIGREEN                      KPI Green Energy Ltd  1212.65     65.45
# ...

# %%
p=[]
for i in n.ticket:
    p.append(i+".NS")

# %%
print(p)
# Out:
# ['CHEVIOT.NS', 'SUBROS.NS', 'SANDUMA.NS', 'NETWEB.NS', 'INOXWIND.NS', 'MANGLMCEM.NS', 'STEELCAS.NS', 'NRBBEARING.NS', 'CENTURYPLY.NS', 'STAR.NS', 'KPIGREEN.NS', 'BSHSL.NS', 'GANDHAR.NS', 'SHREEPUSHK.NS']

# %%
'MHLXMIRU', 'BIL',
# Out:
# ('MHLXMIRU', 'BIL')

# %%
import yfinance as yf

# %%
df_MHLXMIRU_d=yf.download("MHLXMIRU.NS",start="2013-11-11",end="2023-11-22",interval="1d")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df_MHLXMIRU_d.head(5)
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2022-01-27  72.000000  82.800003  72.000000  74.550003  74.550003  148675
# 2022-01-28  77.400002  82.000000  72.150002  75.699997  75.699997   94926
# 2022-01-31  80.500000  80.500000  71.000000  71.349998  71.349998   68741
# 2022-02-01  65.199997  78.000000  65.199997  72.849998  72.849998   66477
# 2022-02-02  75.000000  76.650002  72.500000  74.099998  74.099998   42919

# %%
df_MHLXMIRU_d.shape
# Out:
# (449, 6)

# %%
df_MHLXMIRU_d['Close'].max()
# Out:
# 304.6499938964844

# %%
df_MHLXMIRU_d['Close'].min()
# Out:
# 71.3499984741211

# %%
df_MHLXMIRU_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 449 entries, 2022-01-27 to 2023-11-21
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       449 non-null    float64
#  1   High       449 non-null    float64
#  2   Low        449 non-null    float64
#  3   Close      449 non-null    float64
#  4   Adj Close  449 non-null    float64
#  5   Volume     449 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 24.6 KB

# %%
df_MHLXMIRU_d[(min(df_MHLXMIRU_d['Close'])]
# Out:
#   Cell In[132], line 1
#     df_MHLXMIRU_d[(min(df_MHLXMIRU_d['Close'])]
#                                               ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '('

# %%
df_MHLXMIRU_d[df_MHLXMIRU_d['Close']==df_MHLXMIRU_d['Close'].min()]
# Out:
#             Open  High   Low      Close  Adj Close  Volume
# Date
# 2022-01-31  80.5  80.5  71.0  71.349998  71.349998   68741

# %%
df_MHLXMIRU_d[df_MHLXMIRU_d['Close']==df_MHLXMIRU_d['Close'].max()]
# Out:
#                   Open        High         Low       Close   Adj Close  Volume
# Date
# 2023-04-11  288.700012  305.450012  285.950012  304.649994  304.649994  185869

# %%
daily_closing_prices = [100.2, 101.5, 102.3, ...]  # Your data goes here

# Generate date range for 10 years (daily frequency)
dates = pd.date_range(start='2013-01-01', periods=len(daily_closing_prices), freq='D')

# Create a DataFrame with Date as index and Closing Prices
df = pd.DataFrame({'Close': daily_closing_prices}, index=dates)

# Calculate daily returns
df['Daily_Return'] = df['Close'].pct_change()

# Resample the DataFrame to get monthly returns
monthly_returns = df['Daily_Return'].resample('M').apply(lambda x: (x + 1).prod() - 1)

# Output the DataFrame with year-month-day as index
print(monthly_returns)

# %%
df_MHLXMIRU_d['Daily_Return']=df_MHLXMIRU_d['Close'].pct_change()

# %%
df_MHLXMIRU_d.head()
# Out:
#                  Open       High        Low      Close  Adj Close  Volume  \
# Date
# 2022-01-27  72.000000  82.800003  72.000000  74.550003  74.550003  148675
# 2022-01-28  77.400002  82.000000  72.150002  75.699997  75.699997   94926
# 2022-01-31  80.500000  80.500000  71.000000  71.349998  71.349998   68741
# 2022-02-01  65.199997  78.000000  65.199997  72.849998  72.849998   66477
# 2022-02-02  75.000000  76.650002  72.500000  74.099998  74.099998   42919
#
#             Daily_Return
# Date
# 2022-01-27           NaN
# 2022-01-28      0.015426
# 2022-01-31     -0.057464
# 2022-02-01      0.021023
# 2022-02-02      0.017159

# %%
df_MHLXMIRU_d['Daily_Return'].dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[145], line 1
# ----> 1 df_MHLXMIRU_d['Daily_Return'].dtypes()
#
# TypeError: 'numpy.dtypes.ObjectDType' object is not callable

# %%
mon=df_MHLXMIRU_d['Close'].pct_change

# %%
df_MHLXMIRU_d.shape
# Out:
# (449, 7)

# %%
mon.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[149], line 1
# ----> 1 mon.shape
#
# AttributeError: 'function' object has no attribute 'shape'

# %%
for i in mon:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[151], line 1
# ----> 1 for i in mon:
#       2     print(i)
#
# TypeError: 'method' object is not iterable

# %%
df_MHLXMIRU_d.dtypes
# Out:
# Open            float64
# High            float64
# Low             float64
# Close           float64
# Adj Close       float64
# Volume            int64
# Daily_Return     object
# dtype: object

# %%
df_MHLXMIRU_d.p


df.pct_change(axis='columns', periods=-1)

# %%
mon=df_MHLXMIRU_d['Close'].pct_change()

# %%
mon
# Out:
# Date
# 2022-01-27         NaN
# 2022-01-28    0.015426
# 2022-01-31   -0.057464
# 2022-02-01    0.021023
# 2022-02-02    0.017159
#                 ...
# 2023-11-15   -0.040266
# 2023-11-16    0.000000
# 2023-11-17    0.018880
# 2023-11-20   -0.027177
# 2023-11-21    0.000212
# Name: Close, Length: 449, dtype: float64

# %%
monthly_returns = df_MHLXMIRU_d['Daily_Return'].resample('M').apply(lambda x: (x + 1).prod() - 1)

# %%
monthly_returns
# Out:
# Date
# 2022-01-31   -0.042924
# 2022-02-28    0.755431
# 2022-03-31   -0.042315
# 2022-04-30    0.165903
# 2022-05-31   -0.066142
# 2022-06-30   -0.096095
# 2022-07-31    0.104617
# 2022-08-31    0.199003
# 2022-09-30   -0.012792
# 2022-10-31    0.225462
# 2022-11-30    0.173936
# 2022-12-31    0.188696
# 2023-01-31   -0.028793
# 2023-02-28    0.136532
# 2023-03-31   -0.039815
# 2023-04-30    0.023056
# 2023-05-31   -0.128756
# 2023-06-30   -0.270704
# 2023-07-31    0.006049
# 2023-08-31   -0.163706
# 2023-09-30    0.127124
# 2023-10-31    0.117715
# 2023-11-30    0.225940
# Freq: M, Name: Daily_Return, dtype: float64

# %%
monthly_returns.shape
# Out:
# (23,)

# %%
df_MHLXMIRU_d.head(1)
# Out:
#             Open       High   Low      Close  Adj Close  Volume  Daily_Return
# Date
# 2022-01-27  72.0  82.800003  72.0  74.550003  74.550003  148675           NaN

# %%
df_MHLXMIRU_d.tail(1)
# Out:
#              Open        High         Low       Close   Adj Close  Volume  \
# Date
# 2023-11-21  240.0  244.850006  233.199997  236.300003  236.300003    8551
#
#             Daily_Return
# Date
# 2023-11-21      0.000212

# %%
monthly_returns.info()
# Out:
# <class 'pandas.core.series.Series'>
# DatetimeIndex: 23 entries, 2022-01-31 to 2023-11-30
# Freq: M
# Series name: Daily_Return
# Non-Null Count  Dtype
# --------------  -----
# 23 non-null     float64
# dtypes: float64(1)
# memory usage: 368.0 bytes

# %%
monthly_returns.shape
# Out:
# (23,)

# %%
monthly_returns=monthly_returns.apply(lambda x:x*100)

# %%
monthly_returns=monthly_returns.round(2)

# %%
monthly_returns[monthly_returns.max()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[174], line 1
# ----> 1 monthly_returns[monthly_returns.max()]
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\series.py:1007, in Series.__getitem__(self, key)
#    1004     return self._values[key]
#    1006 elif key_is_scalar:
# -> 1007     return self._get_value(key)
#    1009 if is_hashable(key):
#    1010     # Otherwise index.get_value will raise InvalidIndexError
#    1011     try:
#    1012         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\series.py:1116, in Series._get_value(self, label, takeable)
#    1113     return self._values[label]
#    1115 # Similar to Index.get_value, but we do not fall back to positional
# -> 1116 loc = self.index.get_loc(label)
#    1118 if is_integer(loc):
# ...

# %%
monthly_returns[]
# Out:
# Date
# 2022-01-31    -4.29
# 2022-02-28    75.54
# 2022-03-31    -4.23
# 2022-04-30    16.59
# 2022-05-31    -6.61
# 2022-06-30    -9.61
# 2022-07-31    10.46
# 2022-08-31    19.90
# 2022-09-30    -1.28
# 2022-10-31    22.55
# 2022-11-30    17.39
# 2022-12-31    18.87
# 2023-01-31    -2.88
# 2023-02-28    13.65
# 2023-03-31    -3.98
# 2023-04-30     2.31
# 2023-05-31   -12.88
# 2023-06-30   -27.07
# 2023-07-31     0.60
# 2023-08-31   -16.37
# 2023-09-30    12.71
# 2023-10-31    11.77
# 2023-11-30    22.59
# Freq: M, Name: Daily_Return, dtype: float64

# %%
df_MHLXMIRU_d=yf.download("MHLXMIRU.NS",start="2013-11-11",end="2023-11-22",interval="1d")

# %%
p
# Out:
# ['MHLXMIRU',
#  'BIL',
#  'ORCHPHARMA',
#  'CREATIVE',
#  'KIOCL',
#  'SIGMA',
#  'BSHSL',
#  'SCHNEIDER',
#  'SOBHA',
#  'APTUS',
#  'SGIL',
#  'NELCO',
#  'TEMBO',
#  'DHANUKA',
#  'MAHLOG']

# %%
q=[]
for i in range(3):
    q.append(i)

# %%
len(q)
# Out:
# 3

# %%
for i in q:
    df_{i}_d=yf.download(f"{i}.NS",start="2013-11-11",end="2023-12-10",interval="1d")

# %%
import yfinance as yf

q = ['AAPL', 'GOOGL', 'MSFT']  # List of stock symbols (replace this with your desired symbols)

dataframes = {}  # Create an empty dictionary to store DataFrames

for i in q:
    dataframes[i] = yf.download(f"{i}", start="2013-11-11", end="2023-12-10", interval="1d")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
p
# Out:
# ['MHLXMIRU.NX',
#  'BIL.NX',
#  'ORCHPHARMA.NX',
#  'CREATIVE.NX',
#  'KIOCL.NX',
#  'SIGMA.NX',
#  'BSHSL.NX',
#  'SCHNEIDER.NX',
#  'SOBHA.NX',
#  'APTUS.NX',
#  'SGIL.NX',
#  'NELCO.NX',
#  'TEMBO.NX',
#  'DHANUKA.NX',
#  'MAHLOG.NX']

# %%
df_MHLXMIRU_d=yf.download("MHLXMIRU.NS",start="2013-11-11",end="2023-11-22",interval="1d")

# %%
dataframes.keys()
# Out:
# dict_keys(['AAPL', 'GOOGL', 'MSFT'])

# %%
df_sh={}
for i in p:
    df_sh[i] = yf.download(f"{i}", start="2010-11-11", end="2023-12-10", interval="1d")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
df_sh.keys()
# Out:
# dict_keys(['AAPL', 'GOOGL', 'MSFT'])

# %%
p=[]
for i in n.ticket:
    p.append(i)

# %%
n.shape
# Out:
# (15, 6)

# %%
n
# Out:
#         ticket                                   name    price  increase  \
# 1     MHLXMIRU                  Mahalaxmi Rubtech Ltd   263.00     43.80
# 6          BIL             Bhartiya International Ltd   365.30     55.25
# 10  ORCHPHARMA                      Orchid Pharma Ltd   643.00     76.90
# 19    CREATIVE                   Creative Newtech Ltd   780.00     72.95
# 20       KIOCL                              KIOCL Ltd   376.35     34.20
# 21       SIGMA                        Sigma Solve Ltd   467.90     42.50
# 27       BSHSL          Bombay Super Hybrid Seeds Ltd   259.50     22.45
# 32   SCHNEIDER  Schneider Electric Infrastructure Ltd   371.00     30.40
# 35       SOBHA                              Sobha Ltd  1039.00     71.85
# 38       APTUS  Aptus Value Housing Finance India Ltd   317.70     19.10
# 41        SGIL           Synergy Green Industries Ltd   316.00     18.60
# 43       NELCO                              Nelco Ltd   794.00     46.15
# ...

# %%
p
# Out:
# ['MHLXMIRU',
#  'BIL',
#  'ORCHPHARMA',
#  'CREATIVE',
#  'KIOCL',
#  'SIGMA',
#  'BSHSL',
#  'SCHNEIDER',
#  'SOBHA',
#  'APTUS',
#  'SGIL',
#  'NELCO',
#  'TEMBO',
#  'DHANUKA',
#  'MAHLOG']

# %%
df_sh.keys()
# Out:
# dict_keys(['CHEVIOT.NS', 'SUBROS.NS', 'SANDUMA.NS', 'NETWEB.NS', 'INOXWIND.NS', 'MANGLMCEM.NS', 'STEELCAS.NS', 'NRBBEARING.NS', 'CENTURYPLY.NS', 'STAR.NS', 'KPIGREEN.NS', 'BSHSL.NS', 'GANDHAR.NS', 'SHREEPUSHK.NS'])

# %%
MHLXMIRU
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[193], line 1
# ----> 1 MHLXMIRU
#
# NameError: name 'MHLXMIRU' is not defined

# %%
dataframes.keys()
# Out:
# dict_keys(['AAPL', 'GOOGL', 'MSFT'])

# %%
dataframes["AAPL"]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2013-11-11   18.571072   18.631071   18.371786   18.537500   16.251677
# 2013-11-12   18.488214   18.711430   18.464287   18.571787   16.281734
# 2013-11-13   18.500000   18.651787   18.462856   18.593929   16.301140
# 2013-11-14   18.671785   18.902857   18.638214   18.862858   16.536909
# 2013-11-15   18.806429   18.896070   18.731787   18.749643   16.437649
# ...                ...         ...         ...         ...         ...
# 2023-12-04  189.979996  190.050003  187.449997  189.429993  189.429993
# 2023-12-05  190.210007  194.399994  190.179993  193.419998  193.419998
# 2023-12-06  194.449997  194.759995  192.110001  192.320007  192.320007
# 2023-12-07  193.630005  195.000000  193.589996  194.270004  194.270004
# 2023-12-08  194.199997  195.990005  193.669998  195.710007  195.710007
#
#                Volume
# Date
# 2013-11-11  227452400
# 2013-11-12  204276800
# 2013-11-13  197220800
# ...

# %%
df_sh.keys()
# Out:
# dict_keys(['MHLXMIRU.NX', 'BIL.NX', 'ORCHPHARMA.NX', 'CREATIVE.NX', 'KIOCL.NX', 'SIGMA.NX', 'BSHSL.NX', 'SCHNEIDER.NX', 'SOBHA.NX', 'APTUS.NX', 'SGIL.NX', 'NELCO.NX', 'TEMBO.NX', 'DHANUKA.NX', 'MAHLOG.NX'])

# %%
df_sh["MHLXMIRU.NS"]
# Out:
#                   Open        High         Low       Close   Adj Close  Volume
# Date
# 2022-01-27   72.000000   82.800003   72.000000   74.550003   74.550003  148675
# 2022-01-28   77.400002   82.000000   72.150002   75.699997   75.699997   94926
# 2022-01-31   80.500000   80.500000   71.000000   71.349998   71.349998   68741
# 2022-02-01   65.199997   78.000000   65.199997   72.849998   72.849998   66477
# 2022-02-02   75.000000   76.650002   72.500000   74.099998   74.099998   42919
# ...                ...         ...         ...         ...         ...     ...
# 2023-12-04  222.100006  228.000000  222.100006  224.899994  224.899994    6738
# 2023-12-05  226.100006  227.000000  218.600006  220.100006  220.100006    8499
# 2023-12-06  219.600006  225.000000  216.000000  224.149994  224.149994   49952
# 2023-12-07  225.300003  228.449997  217.100006  219.199997  219.199997    6383
# 2023-12-08  219.149994  263.000000  218.899994  263.000000  263.000000  255316
#
# ...

# %%
len(df_sh)
# Out:
# 15

# %%
mon=df_MHLXMIRU_d['Close'].pct_change()

# %%
y=[]
for j in df_sh.keys():
    y.append(j+"_pct")
# Out:
# MHLXMIRU.NS
# BIL.NS
# ORCHPHARMA.NS
# CREATIVE.NS
# KIOCL.NS
# SIGMA.NS
# BSHSL.NS
# SCHNEIDER.NS
# SOBHA.NS
# APTUS.NS
# SGIL.NS
# NELCO.NS
# TEMBO.NS
# DHANUKA.NS
# MAHLOG.NS

# %%
len(df_sh.keys())
# Out:
# 14

# %%
df_sh.keys()
# Out:
# dict_keys(['CHEVIOT.NS', 'SUBROS.NS', 'SANDUMA.NS', 'NETWEB.NS', 'INOXWIND.NS', 'MANGLMCEM.NS', 'STEELCAS.NS', 'NRBBEARING.NS', 'CENTURYPLY.NS', 'STAR.NS', 'KPIGREEN.NS', 'BSHSL.NS', 'GANDHAR.NS', 'SHREEPUSHK.NS'])

# %%
df_sh["CHEVIOT.NS"]
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2022-06-20  1240.099976  1254.000000  1147.550049  1152.550049  1080.485596
# 2022-06-21  1165.000000  1199.000000  1165.000000  1191.599976  1117.093750
# 2022-06-22  1191.599976  1209.550049  1105.000000  1148.300049  1076.501221
# 2022-06-23  1148.000000  1175.400024  1148.000000  1154.000000  1081.844849
# 2022-06-24  1154.050049  1203.949951  1154.050049  1194.650024  1119.953125
# ...                 ...          ...          ...          ...          ...
# 2023-12-04  1247.750000  1251.849976  1226.000000  1236.900024  1236.900024
# 2023-12-05  1250.000000  1255.949951  1225.000000  1230.400024  1230.400024
# 2023-12-06  1225.000000  1238.050049  1224.050049  1229.650024  1229.650024
# 2023-12-07  1232.699951  1246.949951  1220.000000  1223.300049  1223.300049
# 2023-12-08  1206.250000  1324.800049  1206.250000  1268.449951  1268.449951
#
#             Volume
# Date
# 2022-06-20    4450
# ...

# %%
df_sh["CHEVIOT.NS"]['Daily_Return']=df_sh["CHEVIOT.NS"]['Close'].pct_change()

# %%
mon['Close']=mon['Close'].apply(lambda x:x*100)
# Out:
# ---------------------------------------------------------------------------
# DateParseError                            Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\datetimes.py:557, in DatetimeIndex.get_loc(self, key)
#     556 try:
# --> 557     parsed, reso = self._parse_with_reso(key)
#     558 except (ValueError, pytz.NonExistentTimeError) as err:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\datetimes.py:513, in DatetimeIndex._parse_with_reso(self, label)
#     512 def _parse_with_reso(self, label: str):
# --> 513     parsed, reso = super()._parse_with_reso(label)
#     515     parsed = Timestamp(parsed)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\datetimelike.py:267, in DatetimeIndexOpsMixin._parse_with_reso(self, label)
#     265     label = str(label)
# --> 267 parsed, reso_str = parsing.parse_datetime_string_with_reso(label, freqstr)
# ...

# %%
df_sh["CHEVIOT.NS"]
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2022-06-20  1240.099976  1254.000000  1147.550049  1152.550049  1080.485596
# 2022-06-21  1165.000000  1199.000000  1165.000000  1191.599976  1117.093750
# 2022-06-22  1191.599976  1209.550049  1105.000000  1148.300049  1076.501221
# 2022-06-23  1148.000000  1175.400024  1148.000000  1154.000000  1081.844849
# 2022-06-24  1154.050049  1203.949951  1154.050049  1194.650024  1119.953125
# ...                 ...          ...          ...          ...          ...
# 2023-12-04  1247.750000  1251.849976  1226.000000  1236.900024  1236.900024
# 2023-12-05  1250.000000  1255.949951  1225.000000  1230.400024  1230.400024
# 2023-12-06  1225.000000  1238.050049  1224.050049  1229.650024  1229.650024
# 2023-12-07  1232.699951  1246.949951  1220.000000  1223.300049  1223.300049
# 2023-12-08  1206.250000  1324.800049  1206.250000  1268.449951  1268.449951
#
#             Volume  Daily_Return
# Date
# ...

# %%
df_sh["CHEVIOT.NS"]["monthly_returns"] = df_sh["CHEVIOT.NS"]['Daily_Return'].resample('M').apply(lambda x: (x + 1).prod() - 1)

# %%
df_sh["CHEVIOT.NS"]
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2022-06-20  1240.099976  1254.000000  1147.550049  1152.550049  1080.485596
# 2022-06-21  1165.000000  1199.000000  1165.000000  1191.599976  1117.093750
# 2022-06-22  1191.599976  1209.550049  1105.000000  1148.300049  1076.501221
# 2022-06-23  1148.000000  1175.400024  1148.000000  1154.000000  1081.844849
# 2022-06-24  1154.050049  1203.949951  1154.050049  1194.650024  1119.953125
# ...                 ...          ...          ...          ...          ...
# 2023-12-04  1247.750000  1251.849976  1226.000000  1236.900024  1236.900024
# 2023-12-05  1250.000000  1255.949951  1225.000000  1230.400024  1230.400024
# 2023-12-06  1225.000000  1238.050049  1224.050049  1229.650024  1229.650024
# 2023-12-07  1232.699951  1246.949951  1220.000000  1223.300049  1223.300049
# 2023-12-08  1206.250000  1324.800049  1206.250000  1268.449951  1268.449951
#
#             Volume  Daily_Return  monthly_returns
# ...

# %%
monthly_returns= df_sh["CHEVIOT.NS"]['Daily_Return'].resample('M').apply(lambda x: (x + 1).prod() - 1)

# %%
monthly_returns.shape
# Out:
# (19,)

# %%
df_MHLXMIRU_d['Daily_Return'].resample('M').apply(lambda x: (x + 1).prod() - 1)

# %%
df_sh["CHEVIOT.NS"]['monthly_returns']=monthly_returns

# %%
df_sh["CHEVIOT.NS"]
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2022-06-20  1240.099976  1254.000000  1147.550049  1152.550049  1080.485596
# 2022-06-21  1165.000000  1199.000000  1165.000000  1191.599976  1117.093750
# 2022-06-22  1191.599976  1209.550049  1105.000000  1148.300049  1076.501221
# 2022-06-23  1148.000000  1175.400024  1148.000000  1154.000000  1081.844849
# 2022-06-24  1154.050049  1203.949951  1154.050049  1194.650024  1119.953125
# ...                 ...          ...          ...          ...          ...
# 2023-12-04  1247.750000  1251.849976  1226.000000  1236.900024  1236.900024
# 2023-12-05  1250.000000  1255.949951  1225.000000  1230.400024  1230.400024
# 2023-12-06  1225.000000  1238.050049  1224.050049  1229.650024  1229.650024
# 2023-12-07  1232.699951  1246.949951  1220.000000  1223.300049  1223.300049
# 2023-12-08  1206.250000  1324.800049  1206.250000  1268.449951  1268.449951
#
#             Volume  Daily_Return  monthly_returns
# ...

# %%
monthly_returns
# Out:
# Date
# 2022-06-30    0.037742
# 2022-07-31    0.151666
# 2022-08-31   -0.148898
# 2022-09-30   -0.035570
# 2022-10-31    0.072569
# 2022-11-30    0.029191
# 2022-12-31   -0.066661
# 2023-01-31   -0.031076
# 2023-02-28   -0.040356
# 2023-03-31   -0.088954
# 2023-04-30    0.152310
# 2023-05-31   -0.020359
# 2023-06-30    0.062301
# 2023-07-31    0.059830
# 2023-08-31   -0.050193
# 2023-09-30   -0.028333
# 2023-10-31    0.096116
# 2023-11-30   -0.036376
# 2023-12-31    0.037544
# Freq: M, Name: Daily_Return, dtype: float64

# %%
monthly_returns=monthly_returns.apply(lambda x: x**100)

# %%
monthly_returns
# Out:
# Date
# 2022-06-30    0.0
# 2022-07-31    0.0
# 2022-08-31    0.0
# 2022-09-30    0.0
# 2022-10-31    0.0
# 2022-11-30    0.0
# 2022-12-31    0.0
# 2023-01-31    0.0
# 2023-02-28    0.0
# 2023-03-31    0.0
# 2023-04-30    0.0
# 2023-05-31    0.0
# 2023-06-30    0.0
# 2023-07-31    0.0
# 2023-08-31    0.0
# 2023-09-30    0.0
# 2023-10-31    0.0
# 2023-11-30    0.0
# 2023-12-31    0.0
# Freq: M, Name: Daily_Return, dtype: float64

# %%
monthly_returns=monthly_returns.apply(lambda x:x*100)

# %%
monthly_returns=monthly_returns.round(2)

# %%
monthly_returns.sort_values(ascending=False)
# Out:
# Date
# 2023-04-30    15.23
# 2022-07-31    15.17
# 2023-10-31     9.61
# 2022-10-31     7.26
# 2023-06-30     6.23
# 2023-07-31     5.98
# 2022-06-30     3.77
# 2023-12-31     3.75
# 2022-11-30     2.92
# 2023-05-31    -2.04
# 2023-09-30    -2.83
# 2023-01-31    -3.11
# 2022-09-30    -3.56
# 2023-11-30    -3.64
# 2023-02-28    -4.04
# 2023-08-31    -5.02
# 2022-12-31    -6.67
# 2023-03-31    -8.90
# 2022-08-31   -14.89
# Name: Daily_Return, dtype: float64

# %%
import google_data
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['SEPC-RE1.NS']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
for k in df_sh.items():
    k = df_sh[k]['Daily_Return'].resample('M').apply(lambda x: (x + 1).prod() - 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[85], line 2
#       1 for k in df_sh.items():
# ----> 2     k = df_sh[k]['Daily_Return'].resample('M').apply(lambda x: (x + 1).prod() - 1)
#
# TypeError: unhashable type: 'DataFrame'

# %%
df_sh.keys()
# Out:
# dict_keys(['CHEVIOT.NS', 'SUBROS.NS', 'SANDUMA.NS', 'NETWEB.NS', 'INOXWIND.NS', 'MANGLMCEM.NS', 'STEELCAS.NS', 'NRBBEARING.NS', 'CENTURYPLY.NS', 'STAR.NS', 'KPIGREEN.NS', 'BSHSL.NS', 'GANDHAR.NS', 'SHREEPUSHK.NS'])

# %%
df_sh["SUBROS.NS"]
# Out:
#                   Open        High         Low       Close   Adj Close  Volume
# Date
# 2010-11-11   48.099998   50.799999   48.000000   48.200001   40.273544  285313
# 2010-11-12   49.349998   49.349998   46.500000   46.849998   39.145557   60265
# 2010-11-15   46.900002   47.000000   45.400002   46.000000   38.435345   49586
# 2010-11-16   46.900002   46.900002   43.650002   43.900002   36.680683   91410
# 2010-11-18   45.500000   46.650002   43.500000   44.299999   37.014896   92682
# ...                ...         ...         ...         ...         ...     ...
# 2023-12-04  435.950012  443.500000  433.299988  435.649994  435.649994  584965
# 2023-12-05  441.000000  445.000000  436.000000  443.600006  443.600006  410727
# 2023-12-06  447.000000  447.950012  438.399994  442.049988  442.049988  274455
# 2023-12-07  442.100006  448.899994  439.049988  444.500000  444.500000  351615
# 2023-12-08  449.000000  452.000000  443.049988  450.350006  450.350006  565912
#
# ...

# %%
for j in df_sh.keys():
    df_sh[j]['Daily_Return'] = df_sh[j]['Close'].pct_change()

# %%
for j in df_sh.keys():
    df_sh[j]['Daily_Return'] = df_sh[j]['Close'].pct_change()

# %%
df_sh = {}
for i in p:
    df_sh[i] = yf.download(f"{i}", start="2010-11-11", end="2023-12-10", interval="1d")

for j in df_sh.keys():
    df_sh[j]['Daily_Return'] = df_sh[j]['Close'].pct_change()

for k in df_sh.keys():
    df_sh[k] = df_sh[k]['Daily_Return'].resample('M').apply(lambda x: (x + 1).prod() - 1)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
df_sh["SUBROS.NS"]
# Out:
# Date
# 2010-11-30   -0.145228
# 2010-12-31    0.067961
# 2011-01-31   -0.125000
# 2011-02-28   -0.145455
# 2011-03-31   -0.028875
#                 ...
# 2023-08-31   -0.017451
# 2023-09-30   -0.066243
# 2023-10-31   -0.046138
# 2023-11-30    0.147534
# 2023-12-31    0.057532
# Freq: M, Name: Daily_Return, Length: 158, dtype: float64

# %%
df_sh["SANDUMA.NS"]
# Out:
# Date
# 2023-09-30   -0.054133
# 2023-10-31    0.014564
# 2023-11-30    0.010114
# 2023-12-31    0.240851
# Freq: M, Name: Daily_Return, dtype: float64

# %%
len(df_sh["INOXWIND.NS"])
# Out:
# 105

# %%
df_sh.keys()
# Out:
# dict_keys(['CHEVIOT.NS', 'SUBROS.NS', 'SANDUMA.NS', 'NETWEB.NS', 'INOXWIND.NS', 'MANGLMCEM.NS', 'STEELCAS.NS', 'NRBBEARING.NS', 'CENTURYPLY.NS', 'STAR.NS', 'KPIGREEN.NS', 'BSHSL.NS', 'GANDHAR.NS', 'SHREEPUSHK.NS'])

# %%
for i in df_sh.keys():
    print(len(df_sh[i]))
# Out:
# 19
# 158
# 4
# 6
# 105
# 158
# 26
# 158
# 158
# 158
# 30
# 68
# 2
# 100

# %%
len(df_sh.keys())
# Out:
# 14

# %%
lengths = [len(df_sh[key]) for key in df_sh.keys()]
max_length = max(lengths)
data = {key: range(length) for key, length in zip(df_sh.keys(), lengths)}
df = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[97], line 4
#       2 max_length = max(lengths)
#       3 data = {key: range(length) for key, length in zip(df_sh.keys(), lengths)}
# ----> 4 df = pd.DataFrame(data)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
#     708     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710 elif isinstance(data, ma.MaskedArray):
#     711     from numpy.ma import mrecords
#
# ...

# %%
import yfinance as yf
import pandas as pd

# List of 50 stock symbols (you can modify this list with your desired symbols)
stock_symbols = ["AAPL", "MSFT", "GOOGL", "AMZN", "FB", "TSLA", "JPM", "JNJ", "V", "PG",
                 "NVDA", "MA", "UNH", "DIS", "BAC", "PYPL", "HD", "ADBE", "CMCSA", "NFLX",
                 "INTC", "VZ", "CRM", "PEP", "ABT", "KO", "T", "CSCO", "TMO", "MRK",
                 "AVGO", "NKE", "ABBV", "ACN", "NEE", "TMUS", "XOM", "QCOM", "CVX", "MDT",
                 "IBM", "TXN", "AMGN", "HON", "LLY", "LMT", "UNP", "COST", "DHR"]

# Dictionary to store stock data
df_sh = {}

# Fetching stock data for each symbol
for symbol in stock_symbols:
    try:
        # Download data for the symbol from 2010-11-11 to 2023-12-10
        df_sh[symbol] = yf.download(symbol, start="2010-11-11", end="2023-12-10", interval="1d")

        # Calculate daily returns
        df_sh[symbol]['Daily_Return'] = df_sh[symbol]['Close'].pct_change()

        # Resample to get monthly returns
        df_sh[symbol] = df_sh[symbol]['Daily_Return'].resample('M').apply(lambda x: (x + 1).prod() - 1)
    except Exception as e:
        print(f"Error fetching data for {symbol}: {e}")

# Create an empty DataFrame to store monthly returns of all stocks
all_stock_returns = pd.DataFrame()

# Concatenate monthly returns into a single DataFrame
for symbol in df_sh.keys():
    all_stock_returns[symbol] = df_sh[symbol]

# Example: Printing the resulting DataFrame
print(all_stock_returns)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['FB']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Error fetching data for FB: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'Index'
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
ue=[]
for i in df_sh.keys():
    ue.append(i)

# %%
ue
# Out:
# ['AAPL',
#  'MSFT',
#  'GOOGL',
#  'AMZN',
#  'FB',
#  'TSLA',
#  'JPM',
#  'JNJ',
#  'V',
#  'PG',
#  'NVDA',
#  'MA',
#  'UNH',
#  'DIS',
#  'BAC',
#  'PYPL',
#  'HD',
#  'ADBE',
#  'CMCSA',
#  'NFLX',
#  'INTC',
#  'VZ',
#  'CRM',
#  'PEP',
#  'ABT',
#  'KO',
#  'T',
#  'CSCO',
#  'TMO',
#  'MRK',
#  'AVGO',
#  'NKE',
#  'ABBV',
#  'ACN',
#  'NEE',
#  'TMUS',
#  'XOM',
#  'QCOM',
#  'CVX',
#  'MDT',
#  'IBM',
#  'TXN',
#  'AMGN',
#  'HON',
#  'LLY',
#  'LMT',
#  'UNP',
#  'COST',
#  'DHR']

# %%
len(ue)
# Out:
# 49

# %%
df["ticket"]
# Out:
# 0          ARVEE
# 1       BAGFILMS
# 2          IREDA
# 3      ENERGYDEV
# 4        CALSOFT
# 5        FCSSOFT
# 6        SHRENIK
# 7        VIVIDHA
# 8     NILASPACES
# 9      BHAGYANGR
# 10          BRNL
# 11     PALREDTEC
# 12     INVENTURE
# 13       CHEVIOT
# 14         EXCEL
# 15        SUBROS
# 16       SANDUMA
# 17      SEPC-RE1
# 18          HOVS
# 19        AAKASH
# 20       AAATECH
# 21       J&KBANK
# 22       ARSHIYA
# 23      GTLINFRA
# 24    PRITIKAUTO
# 25    LCCINFOTEC
# 26        NETWEB
# 27      INOXWIND
# 28         PURVA
# 29    MAHAPEXLTD
# 30     MANGLMCEM
# 31       MANOMAY
# 32          IRFC
# 33      STEELCAS
# 34    NRBBEARING
# 35    CORDSCABLE
# 36    MODISONLTD
# 37     COFFEEDAY
# 38     LYPSAGEMS
# 39      PRECWIRE
# 40    CENTURYPLY
# 41          STAR
# 42      KPIGREEN
# 43         BSHSL
# 44      IMAGICAA
# 45       GANDHAR
# 46        MITTAL
# 47    SHREEPUSHK
# 48         ANMOL
# 49    AMBICAAGAR
# Name: ticket, dtype: object

# %%
stock_symbols=[]
for i in df["ticket"]:
    stock_symbols.append(i+".NS")
print(stock_symbols)
# Out:
# ['ARVEE.NS', 'BAGFILMS.NS', 'IREDA.NS', 'ENERGYDEV.NS', 'CALSOFT.NS', 'FCSSOFT.NS', 'SHRENIK.NS', 'VIVIDHA.NS', 'NILASPACES.NS', 'BHAGYANGR.NS', 'BRNL.NS', 'PALREDTEC.NS', 'INVENTURE.NS', 'CHEVIOT.NS', 'EXCEL.NS', 'SUBROS.NS', 'SANDUMA.NS', 'SEPC-RE1.NS', 'HOVS.NS', 'AAKASH.NS', 'AAATECH.NS', 'J&KBANK.NS', 'ARSHIYA.NS', 'GTLINFRA.NS', 'PRITIKAUTO.NS', 'LCCINFOTEC.NS', 'NETWEB.NS', 'INOXWIND.NS', 'PURVA.NS', 'MAHAPEXLTD.NS', 'MANGLMCEM.NS', 'MANOMAY.NS', 'IRFC.NS', 'STEELCAS.NS', 'NRBBEARING.NS', 'CORDSCABLE.NS', 'MODISONLTD.NS', 'COFFEEDAY.NS', 'LYPSAGEMS.NS', 'PRECWIRE.NS', 'CENTURYPLY.NS', 'STAR.NS', 'KPIGREEN.NS', 'BSHSL.NS', 'IMAGICAA.NS', 'GANDHAR.NS', 'MITTAL.NS', 'SHREEPUSHK.NS', 'ANMOL.NS', 'AMBICAAGAR.NS']

# %%
df_sh = {}

# Fetching stock data for each symbol
for symbol in stock_symbols:
    try:
        # Download data for the symbol from 2010-11-11 to 2023-12-10
        df_sh[symbol] = yf.download(symbol, start="2010-11-11", end="2023-12-10", interval="1d")

        # Calculate daily returns
        df_sh[symbol]['Daily_Return'] = df_sh[symbol]['Close'].pct_change()

        # Resample to get monthly returns
        df_sh[symbol] = df_sh[symbol]['Daily_Return'].resample('M').apply(lambda x: (x + 1).prod() - 1)
    except Exception as e:
        print(f"Error fetching data for {symbol}: {e}")

# Create an empty DataFrame to store monthly returns of all stocks
all_stock_returns = pd.DataFrame()

# Concatenate monthly returns into a single DataFrame
for symbol in df_sh.keys():
    all_stock_returns[symbol] = df_sh[symbol]

# Example: Printing the resulting DataFrame
print(all_stock_returns)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
import yfinance as yf
import pandas as pd

# Fetching data for a single stock ('SEPC-RE1.NS' in this example)
df_sh = {}
stock_symbol = 'SEPC-RE1.NS'

try:
    # Download data for the symbol from 2010-11-11 to 2023-12-10
    df_sh[stock_symbol] = yf.download(stock_symbol, start="2010-11-11", end="2023-12-10", interval="1d")

    # Calculate daily returns
    df_sh[stock_symbol]['Daily_Return'] = df_sh[stock_symbol]['Close'].pct_change()

    # Resample to get monthly returns
    df_sh[stock_symbol] = df_sh[stock_symbol]['Daily_Return'].resample('M').apply(lambda x: (x + 1).prod() - 1)
except Exception as e:
    print(f"Error fetching data for {stock_symbol}: {e}")

# Now, let's add the monthly returns of 'SEPC-RE1.NS' to a target DataFrame

# Create a target DataFrame (example)
target_df = pd.DataFrame()

# Assuming 'SEPC-RE1.NS' data is in df_sh['SEPC-RE1.NS']
if stock_symbol in df_sh:
    target_df[stock_symbol] = df_sh[stock_symbol]

# Example: Printing the resulting DataFrame
print(target_df)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['SEPC-RE1.NS']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# Error fetching data for SEPC-RE1.NS: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'Index'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[107], line 27
#      25 # Assuming 'SEPC-RE1.NS' data is in df_sh['SEPC-RE1.NS']
#      26 if stock_symbol in df_sh:
# ---> 27     target_df[stock_symbol] = df_sh[stock_symbol]
#      29 # Example: Printing the resulting DataFrame
#      30 print(target_df)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:3940, in DataFrame.__setitem__(self, key, value)
#    3938     self._setitem_array(key, value)
#    3939 elif isinstance(value, DataFrame):
# ...

# %%
for i in stock_symbols:
    if i=="SEPC-RE1.NS":
        print('y')
# Out:
# y

# %%
len(stock_symbols)
# Out:
# 50

# %%
stock_symbols.remove("SEPC-RE1.NS")

# %%
len(stock_symbols)
# Out:
# 49

# %%
all_stock_returns
# Out:
#             ARVEE.NS   BAGFILMS.NS  IREDA.NS  ENERGYDEV.NS  CALSOFT.NS  \
# Date
# 2018-02-28 -0.102400  4.424779e-02       NaN     -0.090211   -0.015625
# 2018-03-31  0.085562 -2.457628e-01       NaN     -0.242616   -0.292398
# 2018-04-30 -0.055829  2.022472e-01       NaN      0.167131   -0.080283
# 2018-05-31 -0.024348 -2.803740e-02       NaN     -0.147971   -0.139923
# 2018-06-30 -0.090909 -1.346154e-01       NaN     -0.159664   -0.152239
# ...              ...           ...       ...           ...         ...
# 2023-08-31 -0.075000  1.382979e-01       NaN      0.047337   -0.024138
# 2023-09-30  0.025676  9.345830e-03       NaN      0.135593    0.017668
# 2023-10-31 -0.024155 -3.330669e-16       NaN     -0.119403   -0.076389
# 2023-11-30  0.256076  1.388889e-01  0.088333      0.073446    0.063910
# 2023-12-31  0.135794  1.382114e-01  0.084992      0.147368    0.084806
#
#             FCSSOFT.NS  SHRENIK.NS  VIVIDHA.NS  NILASPACES.NS  BHAGYANGR.NS  \
# Date
# ...

# %%
all_stock_returns.to_csv("all_stock_returns.csv")

# %%
all_stock_returns[all_stock_returns.isnull()==True].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
all_stock_returns=all_stock_returns.apply(lambda x: x*100).round(2)

# %%
all_stock_returns
# Out:
#             ARVEE.NS  BAGFILMS.NS  IREDA.NS  ENERGYDEV.NS  CALSOFT.NS  \
# Date
# 2018-02-28    -10.24         4.42       NaN         -9.02       -1.56
# 2018-03-31      8.56       -24.58       NaN        -24.26      -29.24
# 2018-04-30     -5.58        20.22       NaN         16.71       -8.03
# 2018-05-31     -2.43        -2.80       NaN        -14.80      -13.99
# 2018-06-30     -9.09       -13.46       NaN        -15.97      -15.22
# ...              ...          ...       ...           ...         ...
# 2023-08-31     -7.50        13.83       NaN          4.73       -2.41
# 2023-09-30      2.57         0.93       NaN         13.56        1.77
# 2023-10-31     -2.42        -0.00       NaN        -11.94       -7.64
# 2023-11-30     25.61        13.89      8.83          7.34        6.39
# 2023-12-31     13.58        13.82      8.50         14.74        8.48
#
#             FCSSOFT.NS  SHRENIK.NS  VIVIDHA.NS  NILASPACES.NS  BHAGYANGR.NS  \
# Date
# ...

# %%
dfi=pd.read_csv("D:\Downloads\MW-Pre-Open-Market-11-Dec-2023.csv")

# %%
dfi.head(5)
# Out:
#   SYMBOL \n PREV. CLOSE \n  IEP \n CHNG \n %CHNG \n FINAL \n  \
# 0     ARVEE         158.50  190.20   31.70    20.00   190.20
# 1    SUBROS         450.35  530.00   79.65    17.69   530.00
# 2  BAGFILMS           7.00    7.90    0.90    12.86     7.90
# 3   MANOMAY         151.75  168.00   16.25    10.71   168.00
# 4  STEELCAS         579.95  640.00   60.05    10.35   640.00
#
#   FINAL QUANTITY \n VALUE \n (₹ Crores) FFM CAP \n (₹ Crores) NM 52W H \n  \
# 0            12,680                0.24                     -      185.05
# 1            64,941                3.44                     -      520.90
# 2            74,776                0.06                     -        7.15
# 3            11,026                0.19                     -      168.35
# 4             6,471                0.41                     -      747.00
#
#   NM 52W L \n
# 0       84.10
# 1      271.05
# 2        3.50
# 3      110.05
# 4      432.00

# %%
stock_symbols=[]
for i in dfi["SYMBOL \n"]:
    stock_symbols.append(i+".NS")

# %%
ye
# Out:
# ['ARVEE.NS',
#  'SUBROS.NS',
#  'BAGFILMS.NS',
#  'MANOMAY.NS',
#  'STEELCAS.NS',
#  'KOTYARK.NS',
#  'ARSHIYA.NS',
#  'AMBICAAGAR.NS',
#  'BHAGYANGR.NS',
#  'MHLXMIRU.NS',
#  'AAKASH.NS',
#  'FCSSOFT.NS',
#  'ACL.NS',
#  'PALREDTEC.NS',
#  'LCCINFOTEC.NS',
#  'CYBERMEDIA.NS',
#  'DELTAMAGNT.NS',
#  'PERFECT.NS',
#  'NILASPACES.NS',
#  'LYPSAGEMS.NS',
#  'MOHITIND.NS',
#  'SUPREMEENG.NS',
#  'CENTEXT.NS',
#  'URAVI.NS',
#  'SILGO.NS',
#  'RCOM.NS',
#  'KAMATHOTEL.NS',
#  'BEDMUTHA.NS',
#  'REFEX.NS',
#  'ASIANENE.NS',
#  'PRITI.NS',
#  '63MOONS.NS',
#  'VISHNUINFR.NS',
#  'V2RETAIL.NS',
#  'ELGIRUBCO.NS',
#  'GMRP&UI.NS',
#  'ATAM.NS',
#  'KEL.NS',
#  'ZENITHEXPO.NS',
#  'HPIL.NS',
#  'WEL.NS',
#  'ICDSLTD.NS',
#  'CROWN.NS',
#  'MUFIN.NS',
#  'SKIL.NS',
#  'KARMAENG.NS',
#  'JETAIRWAYS.NS',
#  'MDL.NS',
#  'NKIND.NS',
#  'LLOYDSENGG.NS',
#  'JSLL.NS',
#  'HECPROJECT.NS',
#  'PARACABLES.NS',
#  'RUCHINFRA.NS',
#  'IL&FSENGG.NS',
#  'ANSALAPI.NS',
#  'RELCAPITAL.NS',
#  'GVKPIL.NS',
# ...

# %%
df_sh = {}

# Fetching stock data for each symbol
for symbol in stock_symbols:
    try:
        # Download data for the symbol from 2010-11-11 to 2023-12-10
        df_sh[symbol] = yf.download(symbol, start="2010-11-11", end="2023-12-10", interval="1d")

        # Calculate daily returns
        df_sh[symbol]['Daily_Return'] = df_sh[symbol]['Close'].pct_change()

        # Resample to get monthly returns
        df_sh[symbol] = df_sh[symbol]['Daily_Return'].resample('M').apply(lambda x: (x + 1).prod() - 1)
    except Exception as e:
        print(f"Error fetching data for {symbol}: {e}")

# Create an empty DataFrame to store monthly returns of all stocks
all_stock_returns = pd.DataFrame()

# Concatenate monthly returns into a single DataFrame
for symbol in df_sh.keys():
    all_stock_returns[symbol] = df_sh[symbol]

# Example: Printing the resulting DataFrame
print(all_stock_returns)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
all_stock_returns
# Out:
#             ARVEE.NS  SUBROS.NS   BAGFILMS.NS  MANOMAY.NS  STEELCAS.NS  \
# Date
# 2018-02-28 -0.102400  -0.018589  4.424779e-02         NaN          NaN
# 2018-03-31  0.085562  -0.131245 -2.457628e-01         NaN          NaN
# 2018-04-30 -0.055829   0.122918  2.022472e-01         NaN          NaN
# 2018-05-31 -0.024348  -0.030882 -2.803740e-02         NaN          NaN
# 2018-06-30 -0.090909  -0.059631 -1.346154e-01         NaN          NaN
# ...              ...        ...           ...         ...          ...
# 2023-08-31 -0.075000  -0.017451  1.382979e-01   -0.007197     0.299444
# 2023-09-30  0.025676  -0.066243  9.345830e-03    0.038535     0.010814
# 2023-10-31 -0.024155  -0.046138 -3.330669e-16   -0.096988    -0.041071
# 2023-11-30  0.256076   0.147534  1.388889e-01    0.007323    -0.068364
# 2023-12-31  0.135794   0.057532  1.382114e-01    0.225767    -0.067754
#
#               ARSHIYA.NS  AMBICAAGAR.NS  BHAGYANGR.NS  MHLXMIRU.NS  AAKASH.NS  \
# Date
# ...

# %%
all_stock_returns.to_csv("2023_12_11_all_stock_returns.csv")

# %%
df_sh.keys()
# Out:
# dict_keys(['ARVEE.NS', 'SUBROS.NS', 'BAGFILMS.NS', 'MANOMAY.NS', 'STEELCAS.NS', 'KOTYARK.NS', 'ARSHIYA.NS', 'AMBICAAGAR.NS', 'BHAGYANGR.NS', 'MHLXMIRU.NS', 'AAKASH.NS', 'FCSSOFT.NS', 'ACL.NS', 'PALREDTEC.NS', 'LCCINFOTEC.NS', 'CYBERMEDIA.NS', 'DELTAMAGNT.NS', 'PERFECT.NS', 'NILASPACES.NS', 'LYPSAGEMS.NS', 'MOHITIND.NS', 'SUPREMEENG.NS', 'CENTEXT.NS', 'URAVI.NS', 'SILGO.NS', 'RCOM.NS', 'KAMATHOTEL.NS', 'BEDMUTHA.NS', 'REFEX.NS', 'ASIANENE.NS', 'PRITI.NS', '63MOONS.NS', 'VISHNUINFR.NS', 'V2RETAIL.NS', 'ELGIRUBCO.NS', 'GMRP&UI.NS', 'ATAM.NS', 'KEL.NS', 'ZENITHEXPO.NS', 'HPIL.NS', 'WEL.NS', 'ICDSLTD.NS', 'CROWN.NS', 'MUFIN.NS', 'SKIL.NS', 'KARMAENG.NS', 'JETAIRWAYS.NS', 'MDL.NS', 'NKIND.NS', 'LLOYDSENGG.NS', 'JSLL.NS', 'HECPROJECT.NS', 'PARACABLES.NS', 'RUCHINFRA.NS', 'IL&FSENGG.NS', 'ANSALAPI.NS', 'RELCAPITAL.NS', 'GVKPIL.NS', 'SILLYMONKS.NS', 'UNITECH.NS', 'SUULD.NS', 'VARDMNPOLY.NS', 'KSHITIJPOL.NS', 'STEL.NS', 'FLEXITUFF.NS', 'DUCON.NS', 'ACCURACY.NS', 'KAUSHALYA.NS', 'ARENTERP.NS', 
# ...

# %%
df_sh["OSWALSEEDS.NS"]
# Out:
# Date
# 2018-07-31   -0.029668
# 2018-08-31    0.021583
# 2018-09-30   -0.084507
# 2018-10-31   -0.034615
# 2018-11-30    0.015936
#                 ...
# 2023-08-31   -0.089884
# 2023-09-30    0.165979
# 2023-10-31   -0.041077
# 2023-11-30   -0.098227
# 2023-12-31    0.001638
# Freq: M, Name: Daily_Return, Length: 66, dtype: float64

# %%
all_stock_returns
# Out:
#             ARVEE.NS  SUBROS.NS   BAGFILMS.NS  MANOMAY.NS  STEELCAS.NS
# Date
# 2018-02-28 -0.102400  -0.018589  4.424779e-02         NaN          NaN
# 2018-03-31  0.085562  -0.131245 -2.457628e-01         NaN          NaN
# 2018-04-30 -0.055829   0.122918  2.022472e-01         NaN          NaN
# 2018-05-31 -0.024348  -0.030882 -2.803740e-02         NaN          NaN
# 2018-06-30 -0.090909  -0.059631 -1.346154e-01         NaN          NaN
# ...              ...        ...           ...         ...          ...
# 2023-08-31 -0.075000  -0.017451  1.382979e-01   -0.007197     0.299444
# 2023-09-30  0.025676  -0.066243  9.345830e-03    0.038535     0.010814
# 2023-10-31 -0.024155  -0.046138 -3.330669e-16   -0.096988    -0.041071
# 2023-11-30  0.256076   0.147534  1.388889e-01    0.007323    -0.068364
# 2023-12-31  0.135794   0.057532  1.382114e-01    0.225767    -0.067754
#
# [71 rows x 5 columns]

# %%
all_stock_returns
# Out:
#             ARVEE.NS  SUBROS.NS   BAGFILMS.NS  MANOMAY.NS  STEELCAS.NS
# Date
# 2018-02-28 -0.102400  -0.018589  4.424779e-02         NaN          NaN
# 2018-03-31  0.085562  -0.131245 -2.457628e-01         NaN          NaN
# 2018-04-30 -0.055829   0.122918  2.022472e-01         NaN          NaN
# 2018-05-31 -0.024348  -0.030882 -2.803740e-02         NaN          NaN
# 2018-06-30 -0.090909  -0.059631 -1.346154e-01         NaN          NaN
# ...              ...        ...           ...         ...          ...
# 2023-08-31 -0.075000  -0.017451  1.382979e-01   -0.007197     0.299444
# 2023-09-30  0.025676  -0.066243  9.345830e-03    0.038535     0.010814
# 2023-10-31 -0.024155  -0.046138 -3.330669e-16   -0.096988    -0.041071
# 2023-11-30  0.256076   0.147534  1.388889e-01    0.007323    -0.068364
# 2023-12-31  0.135794   0.057532  1.382114e-01    0.225767    -0.067754
#
# [71 rows x 5 columns]

# %%
KOTYARK.NS, PERFECT.NS, VISHNUINFR.NS, KEL.NS,JSLL.NS

BRIGHT.NS

GSTL.NS

RMDRIP.NS

EFACTOR.NS

QUADPRO.NS


SYNOPTICS.NS


HIGREEN.NS

BASILIC.NS


MARINETRAN.NS


SYSTANGO.NS


GREENCHEF.NS


PGINVIT.NS


CELLPOINT.NS

GOYALSALT.NS

CLOUD.NS

CRAYONS.NS


DUCOL.NS

KDL.NS


BETA.NS


SEPC-RE1.NS


ROCKINGDCE.NS



RCDL.NS


ARABIAN.NS

KARNIKA.NS


LRRPL.NS

CBAZAAR.NS

# %%
with open(r'D:\Pyn\online learning\INURAN_DATA\FSDS_September\TEST_WORK\STOCKS\SCRAP_FINA\ie.txt',"r") as new:
    ne=new.readlines()

# %%
len(ne)
# Out:
# 71

# %%
ne[0]
# Out:
# 'KOTYARK.NS, PERFECT.NS, VISHNUINFR.NS, KEL.NS,JSLL.NS\n'

# %%
# Provided string of stock names
stock_names = """
KOTYARK.NS
PERFECT.NS
VISHNUINFR.NS
KEL.NS
JSLL.NS
BRIGHT.NS
GSTL.NS
RMDRIP.NS
EFACTOR.NS
QUADPRO.NS
SYNOPTICS.NS
HIGREEN.NS
BASILIC.NS
MARINETRAN.NS
SYSTANGO.NS
GREENCHEF.NS
PGINVIT.NS
CELLPOINT.NS
GOYALSALT.NS
CLOUD.NS
CRAYONS.NS
DUCOL.NS
KDL.NS
BETA.NS
SEPC-RE1.NS
ROCKINGDCE.NS
RCDL.NS
ARABIAN.NS
KARNIKA.NS
LRRPL.NS
CBAZAAR.NS
"""

# Split the string into a list of names based on newline characters
names_list = [name.strip() for name in stock_names.split('\n') if name.strip()]

# Print the list of names
print(names_list)
# Out:
# ['KOTYARK.NS', 'PERFECT.NS', 'VISHNUINFR.NS', 'KEL.NS', 'JSLL.NS', 'BRIGHT.NS', 'GSTL.NS', 'RMDRIP.NS', 'EFACTOR.NS', 'QUADPRO.NS', 'SYNOPTICS.NS', 'HIGREEN.NS', 'BASILIC.NS', 'MARINETRAN.NS', 'SYSTANGO.NS', 'GREENCHEF.NS', 'PGINVIT.NS', 'CELLPOINT.NS', 'GOYALSALT.NS', 'CLOUD.NS', 'CRAYONS.NS', 'DUCOL.NS', 'KDL.NS', 'BETA.NS', 'SEPC-RE1.NS', 'ROCKINGDCE.NS', 'RCDL.NS', 'ARABIAN.NS', 'KARNIKA.NS', 'LRRPL.NS', 'CBAZAAR.NS']

# %%
names_list
# Out:
# ['KOTYARK.NS',
#  'PERFECT.NS',
#  'VISHNUINFR.NS',
#  'KEL.NS',
#  'JSLL.NS',
#  'BRIGHT.NS',
#  'GSTL.NS',
#  'RMDRIP.NS',
#  'EFACTOR.NS',
#  'QUADPRO.NS',
#  'SYNOPTICS.NS',
#  'HIGREEN.NS',
#  'BASILIC.NS',
#  'MARINETRAN.NS',
#  'SYSTANGO.NS',
#  'GREENCHEF.NS',
#  'PGINVIT.NS',
#  'CELLPOINT.NS',
#  'GOYALSALT.NS',
#  'CLOUD.NS',
#  'CRAYONS.NS',
#  'DUCOL.NS',
#  'KDL.NS',
#  'BETA.NS',
#  'SEPC-RE1.NS',
#  'ROCKINGDCE.NS',
#  'RCDL.NS',
#  'ARABIAN.NS',
#  'KARNIKA.NS',
#  'LRRPL.NS',
#  'CBAZAAR.NS']

# %%
len(stock_symbols)
# Out:
# 1810

# %%
stso=[]
for i in stock_symbols:
    if i not in names_list:
        stso.append(i)

# %%
len(stso)
# Out:
# 1779

# %%
stock_symbols=stso

# %%
all_stock_returns=all_stock_returns.apply(lambda x: x*100).round(2)

# %%
all_stock_returns.to_csv("all_stock_returns_round2.csv")

# %%
all_stock_returns.T
# Out:
# Date           2018-02-28  2018-03-31  2018-04-30  2018-05-31  2018-06-30  \
# ARVEE.NS           -10.24        8.56       -5.58       -2.43       -9.09
# SUBROS.NS           -1.86      -13.12       12.29       -3.09       -5.96
# BAGFILMS.NS          4.42      -24.58       20.22       -2.80      -13.46
# MANOMAY.NS            NaN         NaN         NaN         NaN         NaN
# STEELCAS.NS           NaN         NaN         NaN         NaN         NaN
# ...                   ...         ...         ...         ...         ...
# GALAXYSURF.NS       -3.58       -8.52       -3.74       -5.08       -5.95
# ANTGRAPHIC.NS      -10.00        0.00       -5.56      -17.65      -14.29
# GOENKA.NS           -9.09       10.00       -9.09      -20.00      -25.00
# SANWARIA.NS        -18.38        3.93       -3.53      -19.58      -28.90
# VHL.NS              -7.43      -14.24        6.84      -19.76      -11.14
#
# Date           2018-07-31  2018-08-31  2018-09-30  2018-10-31  2018-11-30  \
# ...

# %%
all_stock_returns.shape
# Out:
# (71, 1769)

# %%
all_stock_returns
# Out:
#             ARVEE.NS  SUBROS.NS  BAGFILMS.NS  MANOMAY.NS  STEELCAS.NS  \
# Date
# 2018-02-28    -10.24      -1.86         4.42         NaN          NaN
# 2018-03-31      8.56     -13.12       -24.58         NaN          NaN
# 2018-04-30     -5.58      12.29        20.22         NaN          NaN
# 2018-05-31     -2.43      -3.09        -2.80         NaN          NaN
# 2018-06-30     -9.09      -5.96       -13.46         NaN          NaN
# ...              ...        ...          ...         ...          ...
# 2023-08-31     -7.50      -1.75        13.83       -0.72        29.94
# 2023-09-30      2.57      -6.62         0.93        3.85         1.08
# 2023-10-31     -2.42      -4.61        -0.00       -9.70        -4.11
# 2023-11-30     25.61      14.75        13.89        0.73        -6.84
# 2023-12-31     13.58       5.75        13.82       22.58        -6.78
#
#             ARSHIYA.NS  AMBICAAGAR.NS  BHAGYANGR.NS  MHLXMIRU.NS  AAKASH.NS  \
# Date
# ...

# %%
all_stock_returns=all_stock_returns.iloc[::-1]

# %%
uew=all_stock_returns.T

# %%
all_stock_returns.to_csv('all_stock_returns_round2.csv')

# %%
uew[(uew["2023-12-31"]>0)==True]
# Out:
# Date         2023-12-31  2023-11-30  2023-10-31  2023-09-30  2023-08-31  \
# ARVEE.NS          13.58       25.61       -2.42        2.57       -7.50
# SUBROS.NS          5.75       14.75       -4.61       -6.62       -1.75
# BAGFILMS.NS       13.82       13.89       -0.00        0.93       13.83
# MANOMAY.NS        22.58        0.73       -9.70        3.85       -0.72
# ARSHIYA.NS        41.33       -0.00      -14.77       -5.38        6.90
# ...                 ...         ...         ...         ...         ...
# SUMIT.NS          22.86       56.97        3.24      -10.61        0.32
# SHRADHA.NS        12.17       42.04        3.15        9.79       -5.95
# EQUIPPP.NS         7.99        6.75       -5.44       -9.04      -18.38
# SANWARIA.NS       25.00       14.29       -0.00      -30.00       66.67
# VHL.NS             0.04        7.01       -7.57        6.27        3.90
#
# Date         2023-07-31  2023-06-30  2023-05-31  2023-04-30  2023-03-31  ...  \
# ...

# %%
len(uew[(uew["2023-12-31"]>0)==True])
# Out:
# 1085

# %%
uew[((uew["2023-12-31"]>0)==True) & ((uew["2023-11-30"]>0)==True)]
# Out:
# Date          2023-12-31  2023-11-30  2023-10-31  2023-09-30  2023-08-31  \
# ARVEE.NS           13.58       25.61       -2.42        2.57       -7.50
# SUBROS.NS           5.75       14.75       -4.61       -6.62       -1.75
# BAGFILMS.NS        13.82       13.89       -0.00        0.93       13.83
# MANOMAY.NS         22.58        0.73       -9.70        3.85       -0.72
# BHAGYANGR.NS        5.14        6.70       -5.95        6.40       -1.65
# ...                  ...         ...         ...         ...         ...
# SUMIT.NS           22.86       56.97        3.24      -10.61        0.32
# SHRADHA.NS         12.17       42.04        3.15        9.79       -5.95
# EQUIPPP.NS          7.99        6.75       -5.44       -9.04      -18.38
# SANWARIA.NS        25.00       14.29       -0.00      -30.00       66.67
# VHL.NS              0.04        7.01       -7.57        6.27        3.90
#
# Date          2023-07-31  2023-06-30  2023-05-31  2023-04-30  2023-03-31  ...  \
# ...

# %%
len(uew[((uew["2023-12-31"]>0)==True) & ((uew["2023-11-30"]>0)==True)]  )
# Out:
# 795

# %%
len(uew[((uew["2023-12-31"]>0)==True) & ((uew["2023-11-30"]>0)==True) & ((uew["2023-10-31"]>0)==True)])
# Out:
# 279

# %%
uew[((uew["2023-12-31"]>0)==True) & ((uew["2023-11-30"]>0)==True) & ((uew["2023-10-31"]>0)==True)]
# Out:
# Date           2023-12-31  2023-11-30  2023-10-31  2023-09-30  2023-08-31  \
# MHLXMIRU.NS         20.17       13.54       11.77       12.71      -16.37
# AAKASH.NS           82.14        6.87       11.97      -15.22       18.97
# FCSSOFT.NS          28.81       11.32        3.92        8.51        4.44
# PALREDTEC.NS         6.56        1.04        5.87      -12.65       15.92
# NILASPACES.NS       21.43        9.37        3.23       -4.62       -2.99
# ...                   ...         ...         ...         ...         ...
# LFIC.NS              1.67        9.38        6.73       -3.31       12.40
# SKYGOLD.NS          13.52       37.72      129.58       15.30        6.50
# COUNCODOS.NS        19.44       25.58        1.18        2.41      -11.70
# SUMIT.NS            22.86       56.97        3.24      -10.61        0.32
# SHRADHA.NS          12.17       42.04        3.15        9.79       -5.95
#
# Date           2023-07-31  2023-06-30  2023-05-31  2023-04-30  2023-03-31  \
# ...

# %%
len(uew[((uew["2023-12-31"]>0)==True) & ((uew["2023-11-30"]>0)==True) & ((uew["2023-10-31"]>0)==True) & ((uew["2023-09-30"]>0)==True)])
# Out:
# 147

# %%
uew[((uew["2023-12-31"]>0)==True) & ((uew["2023-11-30"]>0)==True) & ((uew["2023-10-31"]>0)==True) & ((uew["2023-09-30"]>0)==True)]
# Out:
# Date           2023-12-31  2023-11-30  2023-10-31  2023-09-30  2023-08-31  \
# MHLXMIRU.NS         20.17       13.54       11.77       12.71      -16.37
# FCSSOFT.NS          28.81       11.32        3.92        8.51        4.44
# ASIANENE.NS         25.15       14.48        2.42       20.44       18.75
# V2RETAIL.NS          3.54       15.58       19.10       16.08        1.49
# CROWN.NS             4.88       36.12       15.40       16.89       -1.99
# ...                   ...         ...         ...         ...         ...
# ASHAPURMIN.NS       26.19       20.65        3.67       27.89       27.68
# PALASHSECU.NS        1.06        6.81        1.19        9.58       -1.62
# SKYGOLD.NS          13.52       37.72      129.58       15.30        6.50
# COUNCODOS.NS        19.44       25.58        1.18        2.41      -11.70
# SHRADHA.NS          12.17       42.04        3.15        9.79       -5.95
#
# Date           2023-07-31  2023-06-30  2023-05-31  2023-04-30  2023-03-31  \
# ...

# %%
len(uew[((uew["2023-12-31"]>0)==True) & ((uew["2023-11-30"]>0)==True) & ((uew["2023-10-31"]>0)==True) & ((uew["2023-09-30"]>0)==True) & ((uew["2023-08-31"]>0)==True)])
# Out:
# 83

# %%
uew[((uew["2023-12-31"]>0)==True) & ((uew["2023-11-30"]>0)==True) & ((uew["2023-10-31"]>0)==True) & ((uew["2023-09-30"]>0)==True) & ((uew["2023-08-31"]>0)==True)]
# Out:
# Date           2023-12-31  2023-11-30  2023-10-31  2023-09-30  2023-08-31  \
# FCSSOFT.NS          28.81       11.32        3.92        8.51        4.44
# ASIANENE.NS         25.15       14.48        2.42       20.44       18.75
# V2RETAIL.NS          3.54       15.58       19.10       16.08        1.49
# HECPROJECT.NS        3.02        6.95       10.38        7.93       18.37
# FLEXITUFF.NS        13.75        7.00        2.60        8.17       39.37
# ...                   ...         ...         ...         ...         ...
# DEEPENR.NS           2.80        5.42        0.72        0.66       27.14
# VERTOZ.NS           12.96        8.48        8.15       15.70        1.35
# SOFTTECH.NS          5.46        1.56       23.65       21.40        0.72
# ASHAPURMIN.NS       26.19       20.65        3.67       27.89       27.68
# SKYGOLD.NS          13.52       37.72      129.58       15.30        6.50
#
# Date           2023-07-31  2023-06-30  2023-05-31  2023-04-30  2023-03-31  \
# ...

# %%
len(uew[((uew["2023-12-31"]>0)==True) & ((uew["2023-11-30"]>0)==True) & ((uew["2023-10-31"]>0)==True) & ((uew["2023-09-30"]>0)==True) & ((uew["2023-08-31"]>0)==True) & ((uew["2023-07-31"]>0)==True)])
# Out:
# 53

# %%
uew[((uew["2023-12-31"]>0)==True) & ((uew["2023-11-30"]>0)==True) & ((uew["2023-10-31"]>0)==True) & ((uew["2023-09-30"]>0)==True) & ((uew["2023-08-31"]>0)==True) & ((uew["2023-07-31"]>0)==True)]
# Out:
# Date           2023-12-31  2023-11-30  2023-10-31  2023-09-30  2023-08-31  \
# FCSSOFT.NS          28.81       11.32        3.92        8.51        4.44
# V2RETAIL.NS          3.54       15.58       19.10       16.08        1.49
# PURVA.NS            16.66       11.32        6.93       21.50        2.41
# ZEEMEDIA.NS         15.15       11.65        2.70        9.28        5.80
# ANANTRAJ.NS          4.12       10.48       10.61        0.05        8.85
# TALBROAUTO.NS        3.59       27.87        8.83        0.03       18.51
# TARC.NS              8.15        9.94        7.70        2.05       30.66
# PNBHOUSING.NS        0.96        5.05        6.09        6.71        2.47
# BIRLAMONEY.NS        4.10        6.32       26.43       13.94       13.43
# MAZDA.NS             0.10        3.98        6.44       15.33       13.24
# RTNPOWER.NS          3.37       24.48        3.62        1.47       36.00
# SBC.NS               1.35        6.10       15.32        8.78       12.12
# ...

# %%
len(uew[((uew["2023-12-31"]>0)==True) & ((uew["2023-11-30"]>0)==True) & ((uew["2023-10-31"]>0)==True) & ((uew["2023-09-30"]>0)==True) & ((uew["2023-08-31"]>0)==True) & ((uew["2023-07-31"]>0)==True) & ((uew["2023-06-30"]>0)==True)])
# Out:
# 36

# %%
uew[((uew["2023-12-31"]>0)==True) & ((uew["2023-11-30"]>0)==True) & ((uew["2023-10-31"]>0)==True) & ((uew["2023-09-30"]>0)==True) & ((uew["2023-08-31"]>0)==True) & ((uew["2023-07-31"]>0)==True) & ((uew["2023-06-30"]>0)==True)]
# Out:
# Date           2023-12-31  2023-11-30  2023-10-31  2023-09-30  2023-08-31  \
# V2RETAIL.NS          3.54       15.58       19.10       16.08        1.49
# PURVA.NS            16.66       11.32        6.93       21.50        2.41
# ZEEMEDIA.NS         15.15       11.65        2.70        9.28        5.80
# ANANTRAJ.NS          4.12       10.48       10.61        0.05        8.85
# TALBROAUTO.NS        3.59       27.87        8.83        0.03       18.51
# TARC.NS              8.15        9.94        7.70        2.05       30.66
# PNBHOUSING.NS        0.96        5.05        6.09        6.71        2.47
# BIRLAMONEY.NS        4.10        6.32       26.43       13.94       13.43
# RTNPOWER.NS          3.37       24.48        3.62        1.47       36.00
# BEARDSELL.NS         0.43        7.69       23.81        5.48       13.86
# JINDRILL.NS          2.77       18.18        6.52       17.85       29.61
# CHENNPETRO.NS        2.34       15.69       12.74       21.58        4.03
# ...

# %%
len(uew[((uew["2023-12-31"]>0)==True) & ((uew["2023-11-30"]>0)==True) & ((uew["2023-10-31"]>0)==True) & ((uew["2023-09-30"]>0)==True) & ((uew["2023-08-31"]>0)==True) & ((uew["2023-07-31"]>0)==True) & ((uew["2023-06-30"]>0)==True) & ((uew["2023-05-31"]>0)==True) ])
# Out:
# 24

# %%
uew[((uew["2023-12-31"]>0)==True) & ((uew["2023-11-30"]>0)==True) & ((uew["2023-10-31"]>0)==True) & ((uew["2023-09-30"]>0)==True) & ((uew["2023-08-31"]>0)==True) & ((uew["2023-07-31"]>0)==True) & ((uew["2023-06-30"]>0)==True) & ((uew["2023-05-31"]>0)==True) ]
# Out:
# Date           2023-12-31  2023-11-30  2023-10-31  2023-09-30  2023-08-31  \
# V2RETAIL.NS          3.54       15.58       19.10       16.08        1.49
# PURVA.NS            16.66       11.32        6.93       21.50        2.41
# ANANTRAJ.NS          4.12       10.48       10.61        0.05        8.85
# TALBROAUTO.NS        3.59       27.87        8.83        0.03       18.51
# TARC.NS              8.15        9.94        7.70        2.05       30.66
# PNBHOUSING.NS        0.96        5.05        6.09        6.71        2.47
# RTNPOWER.NS          3.37       24.48        3.62        1.47       36.00
# BEARDSELL.NS         0.43        7.69       23.81        5.48       13.86
# CHENNPETRO.NS        2.34       15.69       12.74       21.58        4.03
# JYOTHYLAB.NS         4.36       19.82        0.58        3.49       11.72
# RECLTD.NS           16.27       21.24        0.07       20.43       17.59
# WELCORP.NS           1.62       24.73        8.04       20.22        1.65
# ...

# %%
len(uew[((uew["2023-12-31"]>0)==True) & ((uew["2023-11-30"]>0)==True) & ((uew["2023-10-31"]>0)==True) & ((uew["2023-09-30"]>0)==True) & ((uew["2023-08-31"]>0)==True) & ((uew["2023-07-31"]>0)==True) & ((uew["2023-06-30"]>0)==True) & ((uew["2023-05-31"]>0)==True) &((uew["2023-04-30"]>0)==True)  ])
# Out:
# 21

# %%
len(uew[((uew["2023-12-31"]>0)==True) & ((uew["2023-11-30"]>0)==True) & ((uew["2023-10-31"]>0)==True) & ((uew["2023-09-30"]>0)==True) & ((uew["2023-08-31"]>0)==True) & ((uew["2023-07-31"]>0)==True) & ((uew["2023-06-30"]>0)==True) & ((uew["2023-05-31"]>0)==True) &((uew["2023-04-30"]>0)==True) & ((uew["2023-03-31"]>0)==True) ])
# Out:
# 8

# %%
uew[((uew["2023-12-31"]>0)==True) & ((uew["2023-11-30"]>0)==True) & ((uew["2023-10-31"]>0)==True) & ((uew["2023-09-30"]>0)==True) & ((uew["2023-08-31"]>0)==True) & ((uew["2023-07-31"]>0)==True) & ((uew["2023-06-30"]>0)==True) & ((uew["2023-05-31"]>0)==True) &((uew["2023-04-30"]>0)==True) & ((uew["2023-03-31"]>0)==True) ]
# Out:
# Date           2023-12-31  2023-11-30  2023-10-31  2023-09-30  2023-08-31  \
# ANANTRAJ.NS          4.12       10.48       10.61        0.05        8.85
# CHENNPETRO.NS        2.34       15.69       12.74       21.58        4.03
# JYOTHYLAB.NS         4.36       19.82        0.58        3.49       11.72
# RECLTD.NS           16.27       21.24        0.07       20.43       17.59
# WELCORP.NS           1.62       24.73        8.04       20.22        1.65
# MRPL.NS              5.48       16.97        8.47        0.37       14.69
# MAHSEAMLES.NS        4.33       35.57       16.82       14.22        0.61
# LGHL.NS              5.52        9.89       38.15      102.22       45.83
#
# Date           2023-07-31  2023-06-30  2023-05-31  2023-04-30  2023-03-31  \
# ANANTRAJ.NS         13.70       16.64        7.38       15.92       16.61
# CHENNPETRO.NS        4.04        3.23       23.65       27.89        5.74
# JYOTHYLAB.NS        44.45        3.15        7.45        2.23        0.13
# ...

# %%
uew[((uew["2023-12-31"]>10)==True) & ((uew["2023-11-30"]>10)==True) & ((uew["2023-10-31"]>10)==True)]
# Out:
# Date           2023-12-31  2023-11-30  2023-10-31  2023-09-30  2023-08-31  \
# MHLXMIRU.NS         20.17       13.54       11.77       12.71      -16.37
# HDIL.NS             28.57       16.67       15.38       -0.00       15.56
# PRITIKAUTO.NS       26.96       23.65       18.09      -12.35       29.61
# CONSOFINVT.NS       11.44       39.72       21.92        2.45        6.75
# STARTECK.NS         17.51       23.81       12.06       -2.18       -3.91
# WEBELSOLAR.NS       22.51       10.80       18.54       26.72       15.28
# JPASSOCIAT.NS       13.96       16.23       26.36       13.27       36.13
# IWEL.NS             16.76       26.93       18.59       -9.33       -0.14
# PRESTIGE.NS         18.30       30.98       27.07       -6.45        9.44
# HBLPOWER.NS         13.80       21.88       10.62       -0.47       39.84
# INOXWIND.NS         29.54       29.41       12.28       -5.39       -3.55
# SKYGOLD.NS          13.52       37.72      129.58       15.30        6.50
#
# ...

# %%
len(uew[((uew["2023-12-31"]>15)==True) & ((uew["2023-11-30"]>15)==True) & ((uew["2023-10-31"]>15)==True)])
# Out:
# 4

# %%
uew[((uew["2023-12-31"]>15)==True) & ((uew["2023-11-30"]>15)==True) & ((uew["2023-10-31"]>15)==True)]
# Out:
# Date           2023-12-31  2023-11-30  2023-10-31  2023-09-30  2023-08-31  \
# HDIL.NS             28.57       16.67       15.38       -0.00       15.56
# PRITIKAUTO.NS       26.96       23.65       18.09      -12.35       29.61
# IWEL.NS             16.76       26.93       18.59       -9.33       -0.14
# PRESTIGE.NS         18.30       30.98       27.07       -6.45        9.44
#
# Date           2023-07-31  2023-06-30  2023-05-31  2023-04-30  2023-03-31  \
# HDIL.NS            -18.18       17.02      -18.97       13.73      -32.89
# PRITIKAUTO.NS       -5.16        4.18        2.13       17.56      -10.58
# IWEL.NS             28.09       28.24       48.73       -0.04        9.09
# PRESTIGE.NS          2.39       18.95       -1.52       21.70       -0.68
#
# Date           ...  2018-11-30  2018-10-31  2018-09-30  2018-08-31  \
# HDIL.NS        ...        0.74       -3.12      -36.68       36.31
# PRITIKAUTO.NS  ...         NaN         NaN         NaN         NaN
# ...

# %%
uew[((uew["2023-12-31"]>20)==True) & ((uew["2023-11-30"]>20)==True)]
# Out:
# Date           2023-12-31  2023-11-30  2023-10-31  2023-09-30  2023-08-31  \
# 63MOONS.NS          33.72       87.21       -6.24      -15.25       37.78
# ICDSLTD.NS          33.68       29.69       -2.97       10.25       -0.61
# KARMAENG.NS         32.82       76.61       -7.62        6.09       -3.22
# UNITECH.NS          31.25      124.00      -10.71       47.37       35.71
# PRITIKAUTO.NS       26.96       23.65       18.09      -12.35       29.61
# EDUCOMP.NS          28.57       53.66      -19.61       50.00      -10.53
# ATGL.NS             63.21       25.61       -7.98       -3.55       -4.20
# EASTSILK.NS         22.45       40.00      -20.45       18.92       -5.13
# SWSOLAR.NS          20.69       26.98      -27.04       -4.72       -5.67
# INOXWIND.NS         29.54       29.41       12.28       -5.39       -3.55
# EMAMIREAL.NS        30.69       21.73        7.98        3.47       14.27
# TFL.NS              20.92       30.60       -8.96       -4.74        2.43
# ...
