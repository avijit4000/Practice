# %%
import pandas as pd

# %%
df=pd.read_json("D:\Pyn\online learning\INURAN_DATA\FSDS_September\TEST_WORK\STOCKS\scrapy_stokes\scrapdata\scrnerdata\data.json")

# %%
df
# Out:
#    Market Cap  Current Price  High / Low  Stock P/E  Book Value  \
# 0    2,18,337            NaN         NaN        NaN         NaN
# 1         NaN          175.0         NaN        NaN         NaN
# 2         NaN            NaN       178.0        NaN         NaN
# 3         NaN            NaN         NaN       12.5         NaN
# 4         NaN            NaN         NaN        NaN       103.0
# 5         NaN            NaN         NaN        NaN         NaN
# 6         NaN            NaN         NaN        NaN         NaN
# 7         NaN            NaN         NaN        NaN         NaN
# 8         NaN            NaN         NaN        NaN         NaN
# 9         NaN            NaN         NaN        NaN         NaN
# 10        NaN            NaN         NaN        NaN         NaN
# 11        NaN            NaN         NaN        NaN         NaN
# 12        NaN            NaN         NaN        NaN         NaN
# 13        NaN            NaN         NaN        NaN         NaN
# ...
