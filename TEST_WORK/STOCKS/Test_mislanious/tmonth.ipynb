# %%
print("avijit")
# Out:
# avijit

# %%
x="My name is Avijit Biswas"

# %%
print(x.lower())
# Out:
# my name is avijit biswas

# %%
print(x.upper())
# Out:
# MY NAME IS AVIJIT BISWAS

# %%
print(x.capitalize())
# Out:
# My name is avijit biswas

# %%
print(x.title())
# Out:
# My Name Is Avijit Biswas

# %%
print(x.swapcase())
# Out:
# mY NAME IS aVIJIT bISWAS

# %%
x
# Out:
# 'My name is Avijit Biswas'

# %%
x=123

# %%
print(x.isdigit())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 print(x.isdigit())
#
# AttributeError: 'int' object has no attribute 'isdigit'

# %%
x
# Out:
# 123

# %%
x.isdigit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 x.isdigit()
#
# AttributeError: 'int' object has no attribute 'isdigit'

# %%
x="123abc"

# %%
print(x)
# Out:
# 123abc

# %%
x
# Out:
# '123abc'

# %%
print(x.isdigit())
# Out:
# False

# %%
x.isdigit()
# Out:
# False

# %%
x.islower()
# Out:
# True

# %%
x.istitle()
# Out:
# False

# %%
print(x.islower())
# Out:
# True

# %%
print(x.isupper())
# Out:
# False

# %%
print(x.isalnum())
# Out:
# True

# %%
x.count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 x.count()
#
# TypeError: count() takes at least 1 argument (0 given)

# %%
x.isascii()
# Out:
# True

# %%
x=x.replace("a","m")

# %%
x
# Out:
# '123mbc'

# %%
x
# Out:
# '123mbc'

# %%
x.join(" my name is")
# Out:
# ' 123mbcm123mbcy123mbc 123mbcn123mbca123mbcm123mbce123mbc 123mbci123mbcs'

# %%
x
# Out:
# '123mbc'

# %%
"/".join(x)
# Out:
# '1/2/3/m/b/c'

# %%
x.rsplit()
# Out:
# ['123mbc']

# %%
import pandas as pd

# %%
df1 = pd.DataFrame({'lkey': ['foo', 'bar', 'baz', 'foo'],
                    'value': [1, 2, 3, 5]})
df2 = pd.DataFrame({'rkey': ['foo', 'bar', 'baz', 'foo'],
                    'value': [5, 6, 7, 8]})

# %%
df1
# Out:
#   lkey  value
# 0  foo      1
# 1  bar      2
# 2  baz      3
# 3  foo      5

# %%
df2
# Out:
#   rkey  value
# 0  foo      5
# 1  bar      6
# 2  baz      7
# 3  foo      8

# %%
df1.merge(df2,left_on="lkey",right_on="rkey",suffixes=("_left","_right"))
# Out:
#   lkey  value_left rkey  value_right
# 0  foo           1  foo            5
# 1  foo           1  foo            8
# 2  foo           5  foo            5
# 3  foo           5  foo            8
# 4  bar           2  bar            6
# 5  baz           3  baz            7

# %%
df1.merge(df2,left_on="lkey",right_on="rkey",how="inner")
# Out:
#   lkey  value_x rkey  value_y
# 0  foo        1  foo        5
# 1  foo        1  foo        8
# 2  foo        5  foo        5
# 3  foo        5  foo        8
# 4  bar        2  bar        6
# 5  baz        3  baz        7

# %%
df1.merge(df2,left_on="lkey",right_on="rkey",how="outer")
# Out:
#   lkey  value_x rkey  value_y
# 0  foo        1  foo        5
# 1  foo        1  foo        8
# 2  foo        5  foo        5
# 3  foo        5  foo        8
# 4  bar        2  bar        6
# 5  baz        3  baz        7

# %%
df1 = pd.DataFrame(
    {
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    },
    index=[0, 1, 2, 3],
)

# %%
df2 = pd.DataFrame(
    {
        "A": ["A4", "A5", "A6", "A7"],
        "B": ["B4", "B5", "B6", "B7"],
        "C": ["C4", "C5", "C6", "C7"],
        "D": ["D4", "D5", "D6", "D7"],
    },
    index=[4, 5, 6, 7],
)

# %%
df3 = pd.DataFrame(
    {
        "A": ["A8", "A9", "A10", "A11"],
        "B": ["B8", "B9", "B10", "B11"],
        "C": ["C8", "C9", "C10", "C11"],
        "D": ["D8", "D9", "D10", "D11"],
    },
    index=[8, 9, 10, 11],
)

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1,df2,df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
df4 = pd.DataFrame(
    {
        "B": ["B2", "B3", "B6", "B7"],
        "D": ["D2", "D3", "D6", "D7"],
        "F": ["F2", "F3", "F6", "F7"],
    },
    index=[2, 3, 6, 7],
)

# %%
pd.concat([df1,df4],axis=1,ignore_index=True)
# Out:
#      0    1    2    3    4    5    6
# 0   A0   B0   C0   D0  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN
# 2   A2   B2   C2   D2   B2   D2   F2
# 3   A3   B3   C3   D3   B3   D3   F3
# 6  NaN  NaN  NaN  NaN   B6   D6   F6
# 7  NaN  NaN  NaN  NaN   B7   D7   F7

# %%
pd.concat([df4,df1],axis=1,join="inner")
# Out:
#     B   D   F   A   B   C   D
# 2  B2  D2  F2  A2  B2  C2  D2
# 3  B3  D3  F3  A3  B3  C3  D3

# %%
pd.concat([df4,df1],axis=1,join="outer")
# Out:
#      B    D    F    A    B    C    D
# 2   B2   D2   F2   A2   B2   C2   D2
# 3   B3   D3   F3   A3   B3   C3   D3
# 6   B6   D6   F6  NaN  NaN  NaN  NaN
# 7   B7   D7   F7  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN   A0   B0   C0   D0
# 1  NaN  NaN  NaN   A1   B1   C1   D1

# %%
pd.concat([df4,df1],axis=1,join="inner")
# Out:
#     B   D   F   A   B   C   D
# 2  B2  D2  F2  A2  B2  C2  D2
# 3  B3  D3  F3  A3  B3  C3  D3

# %%
pd.concat([df1, df4], axis=1).reindex(df1.index)
# Out:
#     A   B   C   D    B    D    F
# 0  A0  B0  C0  D0  NaN  NaN  NaN
# 1  A1  B1  C1  D1  NaN  NaN  NaN
# 2  A2  B2  C2  D2   B2   D2   F2
# 3  A3  B3  C3  D3   B3   D3   F3

# %%
pd.concat([df1, df4], ignore_index=True, sort=False)
# Out:
#      A   B    C   D    F
# 0   A0  B0   C0  D0  NaN
# 1   A1  B1   C1  D1  NaN
# 2   A2  B2   C2  D2  NaN
# 3   A3  B3   C3  D3  NaN
# 4  NaN  B2  NaN  D2   F2
# 5  NaN  B3  NaN  D3   F3
# 6  NaN  B6  NaN  D6   F6
# 7  NaN  B7  NaN  D7   F7

# %%
left = pd.DataFrame(
    {
        "key": ["K0", "K1", "K2", "K3"],
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
    }
)

# %%
right = pd.DataFrame(
    {
        "key": ["K0", "K1", "K2", "K3"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    }
)

# %%
pd.merge(left,right, on="key", how="outer")
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
pd.merge(left,right, on="key", how="inner")
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
sales_person= {
    'sales_id': [1, 2, 3, 4, 5],
    'name': ['John', 'Amy', 'Mark', 'Pam', 'Alex'],
    'salary': [100000, 12000, 65000, 25000, 5000],
    'commission_rate': [6, 5, 12, 25, 10],
    'hire_date': ['4/1/2006', '5/1/2010', '12/25/2008', '1/1/2005', '2/3/2007']
}

# %%
sales_person
# Out:
# {'sales_id': [1, 2, 3, 4, 5],
#  'name': ['John', 'Amy', 'Mark', 'Pam', 'Alex'],
#  'salary': [100000, 12000, 65000, 25000, 5000],
#  'commission_rate': [6, 5, 12, 25, 10],
#  'hire_date': ['4/1/2006', '5/1/2010', '12/25/2008', '1/1/2005', '2/3/2007']}

# %%
sales_person=pd.DataFrame(sales_person)

# %%
company = {
    'com_id': [1, 2, 3, 4],
    'name': ['RED', 'ORANGE', 'YELLOW', 'GREEN'],
    'city': ['Boston', 'New York', 'Boston', 'Austin']
}
company=pd.DataFrame(company)

# %%
company
# Out:
#    com_id    name      city
# 0       1     RED    Boston
# 1       2  ORANGE  New York
# 2       3  YELLOW    Boston
# 3       4   GREEN    Austin

# %%
orders = {
    'order_id': [1, 2, 3, 4],
    'order_date': ['1/1/2014', '2/1/2014', '3/1/2014', '4/1/2014'],
    'com_id': [3, 4, 1, 1],
    'sales_id': [4, 5, 1, 4],
    'amount': [10000, 5000, 50000, 25000]
}

# Create the DataFrame
orders = pd.DataFrame(orders)

# %%
orders
# Out:
#    order_id order_date  com_id  sales_id  amount
# 0         1   1/1/2014       3         4   10000
# 1         2   2/1/2014       4         5    5000
# 2         3   3/1/2014       1         1   50000
# 3         4   4/1/2014       1         4   25000

# %%
table1=pd.merge(company,orders,on="com_id")

# %%
table1
# Out:
#    com_id    name    city  order_id order_date  sales_id  amount
# 0       1     RED  Boston         3   3/1/2014         1   50000
# 1       1     RED  Boston         4   4/1/2014         4   25000
# 2       3  YELLOW  Boston         1   1/1/2014         4   10000
# 3       4   GREEN  Austin         2   2/1/2014         5    5000

# %%
table1[table1["com_id"]==1][]
# Out:
#    com_id name    city  order_id order_date  sales_id  amount
# 0       1  RED  Boston         3   3/1/2014         1   50000
# 1       1  RED  Boston         4   4/1/2014         4   25000

# %%
sales_person
# Out:
#    sales_id  name  salary  commission_rate   hire_date
# 0         1  John  100000                6    4/1/2006
# 1         2   Amy   12000                5    5/1/2010
# 2         3  Mark   65000               12  12/25/2008
# 3         4   Pam   25000               25    1/1/2005
# 4         5  Alex    5000               10    2/3/2007

# %%
table1
# Out:
#    com_id    name    city  order_id order_date  sales_id  amount
# 0       1     RED  Boston         3   3/1/2014         1   50000
# 1       1     RED  Boston         4   4/1/2014         4   25000
# 2       3  YELLOW  Boston         1   1/1/2014         4   10000
# 3       4   GREEN  Austin         2   2/1/2014         5    5000

# %%
table2=pd.merge(table1,sales_person,on="sales_id",how="outer")

# %%
table3=table2[table2["name_x"]=="RED"]["name_y"]

# %%
table2[~table2["name_y"].isin(table3)]["name_y"]
# Out:
# 3    Alex
# 4     Amy
# 5    Mark
# Name: name_y, dtype: object

# %%
# Assuming table3 is derived as follows:
table3 = table2[table2["name_x"] == "RED"]["name_y"]

# Now filter table2 based on the condition that 'name_y' should not be in 'table3'
filtered_table2 = table2[~table2["name_y"].isin(table3)]

# Display the filtered DataFrame
print(filtered_table2)
# Out:
#    com_id name_x    city  order_id order_date  sales_id  amount name_y  \
# 3     4.0  GREEN  Austin       2.0   2/1/2014         5  5000.0   Alex
# 4     NaN    NaN     NaN       NaN        NaN         2     NaN    Amy
# 5     NaN    NaN     NaN       NaN        NaN         3     NaN   Mark
#
#    salary  commission_rate   hire_date
# 3    5000               10    2/3/2007
# 4   12000                5    5/1/2010
# 5   65000               12  12/25/2008

# %%
filtered_table2
# Out:
#    com_id name_x    city  order_id order_date  sales_id  amount name_y  \
# 3     4.0  GREEN  Austin       2.0   2/1/2014         5  5000.0   Alex
# 4     NaN    NaN     NaN       NaN        NaN         2     NaN    Amy
# 5     NaN    NaN     NaN       NaN        NaN         3     NaN   Mark
#
#    salary  commission_rate   hire_date
# 3    5000               10    2/3/2007
# 4   12000                5    5/1/2010
# 5   65000               12  12/25/2008

# %%
u=[1,5,9,6,8,7,8,9,6,5,5,8]
if u in 5:
    u.pop(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 u=[1,5,9,6,8,7,8,9,6,5,5,8]
# ----> 2 if u in 5:
#       3     u.pop(5)
#
# TypeError: argument of type 'int' is not iterable

# %%
y=u.pop(5)

# %%
y
# Out:
# 8

# %%
u.remove(5)

# %%
u
# Out:
# [1, 9, 6, 8, 9, 6, 5, 5, 8]

# %%
print("Avijit")
# Out:
# Avijit

# %%
print("Biswas")
# Out:
# Biswas

# %%
myset = set(["a", "b", "c"])
print(myset)
# Out:
# {'c', 'b', 'a'}

# %%
set([10,2,9,4,5,6])
# Out:
# {2, 4, 5, 6, 9, 10}

# %%
intervals = [[1,3],[2,6],[8,10],[15,18]]
Output: [[1,6],[8,10],[15,18]]
Explanation: Since intervals [1,3] and [2,6] overlap, merge them into

# %%
intervals = [[1,3],[2,6],[8,10],[15,18]]

# %%
intervals
# Out:
# [[1, 3], [2, 6], [8, 10], [15, 18]]

# %%
for i in intervals:
    for j in i:
        print(j)
# Out:
# 1
# 3
# 2
# 6
# 8
# 10
# 15
# 18

# %%
for i in intervals:
    print(i)
# Out:
# [1, 3]
# [2, 6]
# [8, 10]
# [15, 18]

# %%
for i in intervals:
    print(len(i))
# Out:
# 2
# 2
# 2
# 2

# %%
print(len(intervals))
# Out:
# 4

# %%
print(intervals)
# Out:
# [[1, 3], [2, 6], [8, 10], [15, 18]]

# %%
n=len(intervals)
l,r=0,0
while l<r:

    l+=1
    r-=1

# %%
nums1 = [1,2,3,0,0,0]
m = 3
nums2 = [2,5,6]
n = 3
print(m)
print(n)
# Out:
# 3
# 3

# %%
while n>0:
    if nums1[m-1]>=nums2[n-1] and m>0:
        nums1[m+n-1]=nums1[m-1]
        m-=1
    else:
        nums1[m+n-1]=nums2[n-1]
        n-=1
print(nums1)
# Out:
# [1, 2, 2, 3, 5, 6]

# %%
while n > 0:
    if nums1[m-1] >= nums2[n-1] and m>0:
        nums1[m+n-1] = nums1[m-1]
        m -= 1
    else:
        nums1[m+n-1] = nums2[n-1]
        n -= 1
print(nums1)
# Out:
# [1, 2, 2, 3, 5, 6]

# %%
u=[4,6,9,7,4,8,6]
print(u)
# Out:
# [4, 6, 9, 7, 4, 8, 6]

# %%
i=set(u)
print(i)
# Out:
# {4, 6, 7, 8, 9}

# %%
len(i)
# Out:
# 5

# %%
print(len(u))
# Out:
# 7

# %%
nums = [1,2,3,4,5,6,7]

# %%
k = 3
n = len(nums)
k = k % n

# %%
k
# Out:
# 3

# %%
s = "A man, a plan, a canal: Panama"

# %%
s
# Out:
# 'A man, a plan, a canal: Panama'

# %%
not s[1].isalnum()
# Out:
# True

# %%
from bs4 import BeautifulSoup as bs
import requests

website = 'https://subslikescript.com/movie/Bloody_Daddy-27501039'  # concatenating the homepage with the movies section
result = requests.get(website)
content = result.text
soup = bs(content, 'lxml')

box=soup.find('article',class_='main-article')
title=box.find('h1').get_text()
scrept=box.find('div',class_='full-script').get_text(separator='\n')


# print(title)
# print(scrept)

# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
website = "https://collegedunia.com/usa/finance/doctorate-universities"  # concatenating the homepage with the movies section
result = requests.get(website)
content = result.text
soup = bs(content, 'lxml')

# %%
box=soup.find('tbody',class_='jsx-4182613765')

# %%
title = soup.find_all('tr', class_='jsx-3040859135 automate_client_img_snippet')

# %%
box1=soup.find('table',class_='jsx-4182613765 table listing-table ')

# %%
box1

# %%
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>ERROR: The request could not be satisfied</title>
# </head><body>
# <h1>403 ERROR</h1>
# <h2>The request could not be satisfied.</h2>
# <hr noshade="" size="1px"/>
# Request blocked.
# We can't connect to the server for this app or website at this time. There might be too much traffic or a configuration error. Try again later, or contact the app or website owner.
# <br clear="all"/>
# If you provide content to customers through CloudFront, you can find steps to troubleshoot and help prevent this error by reviewing the CloudFront documentation.
# <br clear="all"/>
# <hr noshade="" size="1px"/>
# <pre>
# Generated by cloudfront (CloudFront)
# Request ID: b8WJkZU8l2dVM5ehPnh8IVEgJ2izbHWi72AXvd6xf5TmPq9k3JBk2g==
# </pre>
# <address>
# </address>
# </body></html>

# %%
from bs4 import BeautifulSoup as bs
import requests

result=requests.get('https://collegedunia.com/usa/finance/doctorate-universities').text
soup=bs(result,'lxml')

# %%
box=soup.find('article',class_='main-article')

# %%
title=box.find('h1').get_text()
transcript=box.find('div',class_="full-script").get_text(strip=True, separator='  \n ')
print(transcript)
with open(f'{title}.txt', 'w') as file_object:
    file_object.write(transcript)

# %%
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>ERROR: The request could not be satisfied</title>
# </head><body>
# <h1>403 ERROR</h1>
# <h2>The request could not be satisfied.</h2>
# <hr noshade="" size="1px"/>
# Request blocked.
# We can't connect to the server for this app or website at this time. There might be too much traffic or a configuration error. Try again later, or contact the app or website owner.
# <br clear="all"/>
# If you provide content to customers through CloudFront, you can find steps to troubleshoot and help prevent this error by reviewing the CloudFront documentation.
# <br clear="all"/>
# <hr noshade="" size="1px"/>
# <pre>
# Generated by cloudfront (CloudFront)
# Request ID: CYgrZJ_vXz9AQPi5S83N-J5fDRpqo2Vxq7O-ny3p6A1z1UE8rWEtXA==
# </pre>
# <address>
# </address>
# </body></html>

# %%
from bs4 import BeautifulSoup as bs
import requests

headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}

result = requests.get('https://collegedunia.com/usa/finance/doctorate-universities/page-2', headers=headers).text
soup = bs(result, 'lxml')

# Now you can start parsing the soup object
print(soup.prettify())  # This will print the formatted HTML of the page
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1,minimum-scale=1.0, maximum-scale=2.0, user-scalable=yes, shrink-to-fit=no,viewport-fit=cover" name="viewport"/>
#   <noscript>
#    <img height="1" src="https://www.facebook.com/tr?id=395139183337257&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#   </noscript>
#   <link as="font" class="jsx-4281398864 jsx-2479196067" crossorigin="anonymous" href="https://images.collegedunia.com/public/asset/font/din/DINPro-Regular.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" class="jsx-4281398864 jsx-2479196067" crossorigin="anonymous" href="https://images.collegedunia.com/public/asset/font/sourcesans_new.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" class="jsx-4281398864 jsx-2479196067" crossorigin="anonymous" href="https://images.collegedunia.com/public/asset/font/din/DINPro-Medium.woff2" rel="preload" type="font/woff2"/>
# ...

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
transcript=soup.find_all('tr',class_="jsx-3040859135 automate_client_img_snippet")

# %%
len(transcript)
# Out:
# 16

# %%
/html/body/div[2]/div[2]/section/div/div[3]/div/div[3]/div[1]/div/table/tbody/
tr[1]/td[2]/span/span/span[1]/span[1]/a/h3/text()[1]

# %%
u=[]
for i in transcript:
    print(i.find('h3',class_="jsx-3040859135 mb-0 d-inline").get_text())
    u.append(i.find('h3',class_="jsx-3040859135 mb-0 d-inline").get_text())

# title=box.find('h1')
# Out:
# Scheller College of Business, Atlanta
# Eli Broad College of Business, East Lansing
# Krannert School of Management, West Lafayette
# Wisconsin School of Business, Madison
# Carlson School of Management, Minneapolis
# Fisher College of Business, Columbus
# School of Business, University of Connecticut, Storrs
# Rutgers Business School, Piscataway
# Gatton College of Business and Economics, Lexington
# Trulaske College of Business, University of Missouri, Columbia
# Fox School of Business and Management, Philadelphia
# Darla Moore School of Business, Columbia
# Sawyer Business School, Boston
# A. Gary Anderson Graduate School of Management, Riverside
# Carroll School of Management, Chestnut Hill
# College of Business, University of Texas at Arlington, Arlington

# %%
u
# Out:
# ['Stanford University, Stanford',
#  'Massachusetts Institute of Technology, Cambridge',
#  'University of California, Berkeley',
#  'Yale University, New Haven',
#  'University of Chicago, Chicago',
#  'University of Pennsylvania, Philadelphia',
#  'Cornell University, Ithaca',
#  'Northwestern University, Evanston',
#  'Georgia Institute of Technology, Atlanta',
#  'University of Illinois, Urbana',
#  'University of Wisconsin, Madison',
#  'University of North Carolina, Chapel Hill',
#  'University of Southern California, Los Angeles',
#  'University of Minnesota - Twin Cities, Minneapolis',
#  'Purdue University, West Lafayette',
#  'Ohio State University, Columbus',
#  'Emory University, Atlanta',
#  'Michigan State University, East Lansing',
#  'Texas A&M University, College Station',
#  'University of Rochester, Rochester',
#  'University of Pittsburgh, Pittsburgh',
#  'Arizona State University, Tempe',
#  'Indiana University, Bloomington',
# ...

# %%
with open('university.txt', 'w') as u1:
    u1.write(u)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 2
#       1 with open('university.txt', 'w') as u1:
# ----> 2     u1.write(u)
#
# TypeError: write() argument must be str, not list

# %%
with open('university1.txt', 'w') as u1:
    for item in u:
        u1.write(f"{item}\n")

# %%
root = 'https://subslikescript.com'  # this is the homepage of the website
website = f'{root}/movies'  # concatenating the homepage with the movies section
result = requests.get(website)
content = result.text
soup = bs(content, 'lxml')
box = soup.find('article', class_='main-article')
links = []
for link in box.find_all('a', href=True):  # find_all returns a list
    links.append(link['href'])
for link in links:
    result = requests.get(f'{root}/{link}')
    content = result.text
    soup = BeautifulSoup(content, 'lxml')
    box = soup.find('article', class_='main-article')
    title = box.find('h1').get_text()
    transcript = box.find('div', class_='full-script').get_text(strip=True, separator=' ')
    with open(f'{title}.txt', 'w') as file:
        file.write(transcript)
