# %%
import yfinance as yf
import matplotlib.pyplot as plt
import ta

data = yf.download('TATAMOTORS.NS', start='2024-05-16', end='2024-05-17',interval="1m")
data.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Datetime
# 2024-05-16 09:15:00+05:30  953.200012  953.200012  949.950012  950.099976
# 2024-05-16 09:16:00+05:30  949.099976  949.099976  944.150024  944.349976
# 2024-05-16 09:17:00+05:30  944.299988  945.849976  943.000000  945.400024
# 2024-05-16 09:18:00+05:30  945.400024  946.000000  943.450012  943.700012
# 2024-05-16 09:19:00+05:30  943.500000  944.000000  941.250000  941.500000
#
#                             Adj Close  Volume
# Datetime
# 2024-05-16 09:15:00+05:30  950.099976       0
# 2024-05-16 09:16:00+05:30  944.349976  407500
# 2024-05-16 09:17:00+05:30  945.400024  218698
# 2024-05-16 09:18:00+05:30  943.700012  152281
# 2024-05-16 09:19:00+05:30  941.500000  223214

# %%
macd_object = ta.trend.MACD(data['Close'])
data['MACD'] = macd_object.macd()
data['MACD_Signal'] = macd_object.macd_signal()
data['MACD_Diff'] = macd_object.macd_diff()
data.tail()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Close'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Plotting
plt.figure(figsize=(14, 7))

# Plotting Close Price
plt.subplot(2, 1, 1)
plt.plot(data['Close'], label='Close Price')
plt.title('Tesla Stock Price and MACD')
plt.legend()

# Plotting MACD
plt.subplot(2, 1, 2)
plt.plot(data['MACD'], label='MACD Line', color='blue')
plt.plot(data['MACD_Signal'], label='Signal Line', color='red')
plt.bar(data.index, data['MACD_Diff'], label='Histogram', color='grey', alpha=0.5)
plt.legend()

plt.show()

# %%
from nselib import capital_market as cm
import nselib as ns
import nselib.derivatives as de
hcal=ns.trading_holiday_calendar()
nifty50=cm.nifty50_equity_list()
data=cm.bhav_copy_equities("22-05-2024")
SBIN=cm.price_volume_and_deliverable_position_data("SBIN",period="1Y")

# %%
macd_object1 = ta.trend.MACD(data['Close'])

# %%
macd_object1 = ta.trend.MACD

# %%
macd_object.macd()
# Out:
# Datetime
# 2024-05-16 09:15:00+05:30         NaN
# 2024-05-16 09:16:00+05:30         NaN
# 2024-05-16 09:17:00+05:30         NaN
# 2024-05-16 09:18:00+05:30         NaN
# 2024-05-16 09:19:00+05:30         NaN
#                                ...
# 2024-05-16 15:25:00+05:30    1.517392
# 2024-05-16 15:26:00+05:30    1.431157
# 2024-05-16 15:27:00+05:30    1.454980
# 2024-05-16 15:28:00+05:30    1.461052
# 2024-05-16 15:29:00+05:30    1.429215
# Name: MACD_12_26, Length: 374, dtype: float64

# %%
[x for x in data["SYMBOL"]]
# Out:
# ['0IHFL26',
#  '0MOFSL26',
#  '1003ISFL28',
#  '1013DLSL24',
#  '1015ECL29',
#  '1018GS2026',
#  '1025NFL25',
#  '1035UCL26',
#  '1040UCL25',
#  '1049DLS25A',
#  '1050ISFL28',
#  '1050NFL26',
#  '1050UCL25',
#  '105IIFL29',
#  '105UCL2026',
#  '1065NFL27',
#  '10CAGL27',
#  '10IIFL28',
#  '10IIFL28A',
#  '10ISFL26',
#  '10NIDO26',
#  '1119NFL27',
#  '11UCL26',
#  '182D010824',
#  '182D031024',
#  '182D050924',
#  '182D060624',
#  '182D071124',
#  '182D110724',
#  '182D111024',
#  '182D130624',
#  '182D150824',
#  '182D181024',
#  '182D190924',
#  '182D260924',
#  '182D290824',
#  '20MICRONS',
#  '21STCENMGM',
#  '360ONE',
#  '364D020525',
#  '364D060325',
#  '364D080525',
#  '364D130325',
#  '364D141124',
#  '364D150525',
#  '364D200225',
#  '364D200325',
#  '364D211124',
#  '364D230125',
#  '364D280624',
#  '364D300524',
#  '3IINFOLTD',
#  '3MINDIA',
#  '3PLAND',
#  '574GS2026',
#  '5PAISA',
#  '63MOONS',
#  '654GS2032',
#  '667GS2035',
#  '667GS2050',
#  '669GS2024',
# ...

# %%
SBIN
# Out:
#     Symbol Series         Date  PrevClose  OpenPrice  HighPrice  LowPrice  \
# 0     SBIN     EQ  22-May-2023     575.15     577.50     580.30    573.45
# 1     SBIN     EQ  23-May-2023     577.15     578.90     583.70    576.80
# 2     SBIN     EQ  24-May-2023     581.60     579.80     585.25    578.25
# 3     SBIN     EQ  25-May-2023     582.70     582.00     582.90    577.00
# 4     SBIN     EQ  26-May-2023     581.25     581.25     587.75    580.55
# ..     ...    ...          ...        ...        ...        ...       ...
# 250   SBIN     EQ  16-May-2024     820.30     825.30     826.15    797.35
# 251   SBIN     EQ  17-May-2024     811.95     814.50     822.45    811.20
# 252   SBIN     EQ  18-May-2024     817.85     822.00     823.00    819.20
# 253   SBIN     EQ  21-May-2024     821.00     821.00     836.30    819.60
# 254   SBIN     EQ  22-May-2024     830.65     826.55     826.65    813.55
#
#      LastPrice  ClosePrice  AveragePrice TotalTradedQuantity  \
# ...
