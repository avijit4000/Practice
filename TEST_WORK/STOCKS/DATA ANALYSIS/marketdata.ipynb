# %%
print("Avijit Biswas")
# Out:
# Avijit Biswas

# %%
from bs4 import BeautifulSoup as bs
import requests as re

# %%
import pandas as pd
import numpy as np
con=re.get('https://www.google.com/finance/markets/gainers?authuser=0').text
soup=bs(con,'lxml')
box=soup.find_all("li")
ue=[]
name=[]
price=[]
increase=[]
pseincre=[]
for i in box:
    name.append(i.find("div",class_="ZvmM7").text)
    price.append(i.find("div",class_="YMlKec").text)
    increase.append(i.find("span",class_="P2Luy Ez2Ioe").text)
    pseincre.append(i.find("div",class_="JwB6zf").text)
df=pd.DataFrame({"name":name,"price":price,"increase":increase,"pseincre":pseincre})
print(df)
# Out:
#                                         name    price increase pseincre
# 0                    Solomon Technology Corp  $132.00  +$12.00   10.00%
# 1                    Calin Technology Co Ltd   $48.45   +$4.40    9.99%
# 2         Nidec Chaun Choung Technology Corp  $319.50  +$29.00    9.98%
# 3              Long Bon International Co Ltd   $22.60   +$2.05    9.98%
# 4                                Jean Co Ltd   $32.55   +$2.95    9.97%
# 5                            C SUN MFG. LTD.  $160.00  +$14.50    9.97%
# 6                       PCL Technologies Inc   $77.60   +$7.00    9.92%
# 7            Mercuries Life Insurance Co Ltd    $7.21   +$0.65    9.91%
# 8         Phoenix Silicon International Corp   $58.80   +$5.30    9.91%
# 9                             Fittech Co Ltd   $63.30   +$5.70    9.90%
# 10              Danen Technology Corporation   $20.55   +$1.85    9.89%
# 11                HORNG SHIUE HOLDING Co Ltd   $18.35   +$1.65    9.88%
# 12                       China Television Co   $22.80   +$2.05    9.88%
# 13                           Ta Jiang Co Ltd   $27.40   +$2.45    9.82%
# 14               Bora Pharmaceuticals Co Ltd  $800.00  +$59.00    7.96%
# 15        Unitech Printed Circuit Board Corp   $38.40   +$2.45    6.82%
# 16                   Gigastorage Corporation   $22.75   +$1.45    6.81%
# 17               Ever Ohms Technology Co Ltd   $28.50   +$1.80    6.74%
# 18            KAULIN MANUFACTURING CO., LTD.   $14.70   +$0.90    6.52%
# 19                      Shin Zu Shing Co Ltd  $188.50  +$11.50    6.50%
# 20  Hung Ching Development&Constructn Co Ltd   $49.25   +$2.85    6.14%
# 21                  Epileds Technologies Inc   $21.75   +$1.25    6.10%
# 22            United Renewable Energy Co Ltd   $12.40   +$0.70    5.98%
# 23                Weikeng Industrial Co. Ltd   $38.40   +$2.15    5.93%
# 24                      Applied BioCode Corp   $21.05   +$1.15    5.78%
# 25          Hong Ho Precision Textile Co Ltd   $53.10   +$2.90    5.78%
# 26                 Eurocharm Holdings Co Ltd  $209.00  +$11.00    5.56%
# 27                   King's Town Bank Co Ltd   $63.30   +$3.30    5.50%
# 28                        Thunder Tiger Corp   $81.50   +$4.10    5.30%
# 29                       PharmaEssentia Corp  $408.50  +$20.50    5.28%
# 30                              Aurotek Corp   $51.30   +$2.50    5.12%
# 31               Lotus Pharmaceutical Co Ltd  $301.00  +$14.00    4.88%
# 32                 Yi Jinn Industrial Co Ltd   $22.60   +$1.05    4.87%
# 33          Continental Holdings Corporation   $35.55   +$1.65    4.87%
# 34                Generalplus Technology Inc   $60.20   +$2.70    4.70%
# 35              Standard Chem & Pharm Co Ltd   $72.10   +$3.20    4.64%
# 36                               Rectron Ltd   $18.35   +$0.80    4.56%
# 37                AzureWave Technologies Inc   $48.60   +$2.10    4.52%
# 38                  SIM Technology Group Ltd    $3.05   +$0.13    4.45%
# 39                         Collins Co., Ltd.   $22.40   +$0.95    4.43%
# 40           Chang Wah Electromaterials Inc.   $49.20   +$2.05    4.35%
# 41                   Fortune Oriental Co Ltd   $15.75   +$0.65    4.30%
# 42                 Elite Advanced Laser Corp   $76.00   +$3.10    4.25%
# 43                          Sun Max Tech Ltd   $60.80   +$2.40    4.11%
# 44                      San Far Property Ltd   $39.75   +$1.55    4.06%
# 45          Chong Hong Construction Co. Ltd.  $128.50   +$5.00    4.05%
# 46         Formosa Oilseed Processing Co Ltd   $72.80   +$2.80    4.00%
# 47                             Groundhog Inc  $144.00   +$5.50    3.97%
# 48                                Ritek Corp    $8.75   +$0.33    3.92%
# 49           Silicon Integrated Systems Corp   $61.00   +$2.30    3.92%

# %%
df = pd.DataFrame({"foo": [1, 2, 3], "bar": [4, 5, 6]})

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
X = np.linspace(0, 2*np.pi, 100)
Y = np.cos(X)

# %%
X
# Out:
# array([0.        , 0.06346652, 0.12693304, 0.19039955, 0.25386607,
#        0.31733259, 0.38079911, 0.44426563, 0.50773215, 0.57119866,
#        0.63466518, 0.6981317 , 0.76159822, 0.82506474, 0.88853126,
#        0.95199777, 1.01546429, 1.07893081, 1.14239733, 1.20586385,
#        1.26933037, 1.33279688, 1.3962634 , 1.45972992, 1.52319644,
#        1.58666296, 1.65012947, 1.71359599, 1.77706251, 1.84052903,
#        1.90399555, 1.96746207, 2.03092858, 2.0943951 , 2.15786162,
#        2.22132814, 2.28479466, 2.34826118, 2.41172769, 2.47519421,
#        2.53866073, 2.60212725, 2.66559377, 2.72906028, 2.7925268 ,
#        2.85599332, 2.91945984, 2.98292636, 3.04639288, 3.10985939,
#        3.17332591, 3.23679243, 3.30025895, 3.36372547, 3.42719199,
#        3.4906585 , 3.55412502, 3.61759154, 3.68105806, 3.74452458,
#        3.8079911 , 3.87145761, 3.93492413, 3.99839065, 4.06185717,
#        4.12532369, 4.1887902 , 4.25225672, 4.31572324, 4.37918976,
#        4.44265628, 4.5061228 , 4.56958931, 4.63305583, 4.69652235,
#        4.75998887, 4.82345539, 4.88692191, 4.95038842, 5.01385494,
#        5.07732146, 5.14078798, 5.2042545 , 5.26772102, 5.33118753,
#        5.39465405, 5.45812057, 5.52158709, 5.58505361, 5.64852012,
#        5.71198664, 5.77545316, 5.83891968, 5.9023862 , 5.96585272,
#        6.02931923, 6.09278575, 6.15625227, 6.21971879, 6.28318531])

# %%
X.shape
# Out:
# (100,)

# %%
Y.shape
# Out:
# (100,)

# %%
fig, ax = plt.subplots()
ax.plot(X,Y)

# %%
from scipy import stats
from numpy.random import default_rng
rng = default_rng()

# %%
for n in [2, 3, 4, 5, 6, 7]:
    x = rng.normal(size=10**n)
    m, k = stats.moment(x, 3), stats.kstat(x, 3)
    print("%.3g %.3g %.3g" % (m, k, m-k))
# Out:
# 0.159 0.164 -0.00489
# -0.0269 -0.027 8.09e-05
# 0.00355 0.00355 -1.07e-06
# 0.0156 0.0156 -4.68e-07
# -0.00543 -0.00543 1.63e-08
# 0.000192 0.000192 -5.76e-11

# %%
fig, ax = plt.subplots(1, 1)

# %%
from scipy.stats import beta
a, b = 2.31, 0.627
mean, var, skew, kurt = beta.stats(a, b, moments='mvsk')

# %%
a
# Out:
# 2.31

# %%
b
# Out:
# 0.627

# %%
mean
# Out:
# 0.7865168539325842

# %%
var
# Out:
# 0.04264874077027537

# %%
skew
# Out:
# -1.1240714863228223

# %%
kurt
# Out:
# 0.5654574834055228

# %%
a, b = 2.31, 0.627
mean, var, skew, kurt = beta.stats(a, b, moments='mvsk')

# %%
mean
# Out:
# 0.7865168539325842

# %%
x = np.linspace(beta.ppf(0.01, a, b),
                beta.ppf(0.99, a, b), 100)
ax.plot(x, beta.pdf(x, a, b),
       'r-', lw=5, alpha=0.6, label='beta pdf')

# %%
rvs(a, b, loc=0, scale=1, size=1, random_state=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 rvs(a, b, loc=0, scale=1, size=1, random_state=None)
#
# NameError: name 'rvs' is not defined

# %%
ax.hist(r, density=True, bins='auto', histtype='stepfilled', alpha=0.2)
ax.set_xlim([x[0], x[-1]])
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 ax.hist(r, density=True, bins='auto', histtype='stepfilled', alpha=0.2)
#       2 ax.set_xlim([x[0], x[-1]])
#       3 ax.legend(loc='best', frameon=False)
#
# NameError: name 'r' is not defined

# %%
r = f.rvs(dfn, dfd, size=1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 r = f.rvs(dfn, dfd, size=1000)
#
# NameError: name 'f' is not defined

# %%
import numpy as np
from scipy.stats import f
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1)

# %%
import numpy as np
from scipy.stats import fisk
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
np.random.seed(19680801)
plt.style.use('bmh')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)

plt.style.use('bmh')


def plot_beta_hist(ax, a, b):
    ax.hist(np.random.beta(a, b, size=10000),
            histtype="stepfilled", bins=25, alpha=0.8, density=True)


fig, ax = plt.subplots()
plot_beta_hist(ax, 10, 10)
plot_beta_hist(ax, 4, 12)
plot_beta_hist(ax, 50, 12)
plot_beta_hist(ax, 6, 55)
ax.set_title("'bmh' style sheet")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('dark_background')

fig, ax = plt.subplots()

L = 6
x = np.linspace(0, L)
ncolors = len(plt.rcParams['axes.prop_cycle'])
shift = np.linspace(0, L, ncolors, endpoint=False)
for s in shift:
    ax.plot(x, np.sin(x + s), 'o-')
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.set_title("'dark_background' style sheet")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('ggplot')

# Fixing random state for reproducibility
np.random.seed(19680801)

fig, axs = plt.subplots(ncols=2, nrows=2)
ax1, ax2, ax3, ax4 = axs.flat

# scatter plot (Note: `plt.scatter` doesn't use default colors)
x, y = np.random.normal(size=(2, 200))
ax1.plot(x, y, 'o')

# sinusoidal lines with colors from default color cycle
L = 2*np.pi
x = np.linspace(0, L)
ncolors = len(plt.rcParams['axes.prop_cycle'])
shift = np.linspace(0, L, ncolors, endpoint=False)
for s in shift:
    ax2.plot(x, np.sin(x + s), '-')
ax2.margins(0)

# bar graphs
x = np.arange(5)
y1, y2 = np.random.randint(1, 25, size=(2, 5))
width = 0.25
ax3.bar(x, y1, width)
ax3.bar(x + width, y2, width,
        color=list(plt.rcParams['axes.prop_cycle'])[2]['color'])
ax3.set_xticks(x + width, labels=['a', 'b', 'c', 'd', 'e'])

# circles with colors from default color cycle
for i, color in enumerate(plt.rcParams['axes.prop_cycle']):
    xy = np.random.normal(size=2)
    ax4.add_patch(plt.Circle(xy, radius=0.3, color=color['color']))
ax4.axis('equal')
ax4.margins(0)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ax = plt.figure().add_subplot(projection='3d')

# Plot a sin curve using the x and y axes.
x = np.linspace(0, 1, 100)
y = np.sin(x * 2 * np.pi) / 2 + 0.5
ax.plot(x, y, zs=0, zdir='z', label='curve in (x, y)')

# Plot scatterplot data (20 2D points per colour) on the x and z axes.
colors = ('r', 'g', 'b', 'k')

# Fixing random state for reproducibility
np.random.seed(19680801)

x = np.random.sample(20 * len(colors))
y = np.random.sample(20 * len(colors))
c_list = []
for c in colors:
    c_list.extend([c] * 20)
# By using zdir='y', the y value of these points is fixed to the zs value 0
# and the (x, y) points are plotted on the x and z axes.
ax.scatter(x, y, zs=0, zdir='y', c=c_list, label='points in (x, z)')

# Make legend, set axes limits and labels
ax.legend()
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.set_zlim(0, 1)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Customize the view angle so it's easier to see that the scatter points lie
# on the plane y=0
ax.view_init(elev=20., azim=-35, roll=0)

plt.show()
