# %%
import yfinance as yf

# %%
df_tm_d=yf.download("TATAMOTORS.NS",start="2013-09-11",end="2023-11-15",interval="1d")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df_tm_d
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2013-09-11  344.801666  346.829895  332.632202  336.837097  334.226257
# 2013-09-12  338.271698  338.370636  326.003296  329.911377  327.354279
# 2013-09-13  328.476746  334.709900  326.596924  330.505005  327.943268
# 2013-09-16  335.402466  337.183380  321.402649  327.833649  325.292633
# 2013-09-17  325.508606  334.066803  324.766541  331.494385  328.924988
# ...                ...         ...         ...         ...         ...
# 2023-11-07  645.000000  649.900024  643.299988  645.000000  645.000000
# 2023-11-08  648.000000  649.049988  641.900024  642.549988  642.549988
# 2023-11-09  644.000000  653.650024  642.700012  649.349976  649.349976
# 2023-11-10  649.349976  652.950012  644.000000  651.049988  651.049988
# 2023-11-13  653.000000  654.000000  649.299988  653.250000  653.250000
#
#               Volume
# Date
# 2013-09-11   9215459
# 2013-09-12   6661518
# 2013-09-13   5971621
# 2013-09-16   5795207
# 2013-09-17   4927964
# ...              ...
# 2023-11-07   6588073
# 2023-11-08   6551864
# 2023-11-09  10155047
# 2023-11-10   6425792
# 2023-11-13   3279829
#
# [2509 rows x 6 columns]

# %%
df_tm_d.head(5)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2013-09-11  344.801666  346.829895  332.632202  336.837097  334.226257
# 2013-09-12  338.271698  338.370636  326.003296  329.911377  327.354279
# 2013-09-13  328.476746  334.709900  326.596924  330.505005  327.943268
# 2013-09-16  335.402466  337.183380  321.402649  327.833649  325.292633
# 2013-09-17  325.508606  334.066803  324.766541  331.494385  328.924988
#
#              Volume
# Date
# 2013-09-11  9215459
# 2013-09-12  6661518
# 2013-09-13  5971621
# 2013-09-16  5795207
# 2013-09-17  4927964

# %%
df_tm_d.shape
# Out:
# (2509, 6)

# %%
df_tm_d.Close
# Out:
# Date
# 2013-09-11    336.837097
# 2013-09-12    329.911377
# 2013-09-13    330.505005
# 2013-09-16    327.833649
# 2013-09-17    331.494385
#                  ...
# 2023-11-07    645.000000
# 2023-11-08    642.549988
# 2023-11-09    649.349976
# 2023-11-10    651.049988
# 2023-11-13    653.250000
# Name: Close, Length: 2509, dtype: float64

# %%
df_tm_d.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
scaler.fit(df_tm_d)
# Out:
# StandardScaler()

# %%
scaled_data=scaler.transform(df_tm_d)

# %%
scaled_data
# Out:
# array([[-0.15462227, -0.17394225, -0.20296961, -0.20681054, -0.21701365,
#         -0.43608261],
#        [-0.20111705, -0.23373871, -0.25063361, -0.25619882, -0.26615137,
#         -0.52109147],
#        [-0.27085921, -0.25961557, -0.24636523, -0.25196558, -0.26193983,
#         -0.54405494],
#        ...,
#        [ 1.97573414,  1.99489513,  2.02651903,  2.02176272,  2.03626153,
#         -0.40480809],
#        [ 2.01382712,  1.98994692,  2.03586636,  2.03388575,  2.04841738,
#         -0.5289377 ],
#        [ 2.03981608,  1.99736903,  2.073975  ,  2.04957434,  2.06414844,
#         -0.63365222]])

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=2)

# %%
pca.fit(scaled_data)
# Out:
# PCA(n_components=2)

# %%
x_pca=pca.transform(scaled_data)

# %%
scaled_data.shape
# Out:
# (2509, 6)

# %%
x_pca.shape
# Out:
# (2509, 2)

# %%
scaled_data
# Out:
# array([[-0.15462227, -0.17394225, -0.20296961, -0.20681054, -0.21701365,
#         -0.43608261],
#        [-0.20111705, -0.23373871, -0.25063361, -0.25619882, -0.26615137,
#         -0.52109147],
#        [-0.27085921, -0.25961557, -0.24636523, -0.25196558, -0.26193983,
#         -0.54405494],
#        ...,
#        [ 1.97573414,  1.99489513,  2.02651903,  2.02176272,  2.03626153,
#         -0.40480809],
#        [ 2.01382712,  1.98994692,  2.03586636,  2.03388575,  2.04841738,
#         -0.5289377 ],
#        [ 2.03981608,  1.99736903,  2.073975  ,  2.04957434,  2.06414844,
#         -0.63365222]])

# %%
x_pca
# Out:
# array([[ 0.30615216, -0.52816633],
#        [ 0.39453457, -0.63856364],
#        [ 0.42477743, -0.6698959 ],
#        ...,
#        [-4.45726604,  0.71965449],
#        [-4.5168988 ,  0.60653525],
#        [-4.58740895,  0.51613383]])

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1],c=df_tm_d['Close'])
plt.xlabel('First principle component')
plt.ylabel('Second principle component')
# Out:
# Text(0, 0.5, 'Second principle component')

# %%
import seaborn as sns

# %%
sns.pairplot(data=df_tm_d)
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df_tm_d_matrix=df_tm_d.corr().round(2)

# %%
df_tm_d_matrix
# Out:
#            Open  High  Low  Close  Adj Close  Volume
# Open       1.00  1.00  1.0   1.00       1.00   -0.49
# High       1.00  1.00  1.0   1.00       1.00   -0.48
# Low        1.00  1.00  1.0   1.00       1.00   -0.50
# Close      1.00  1.00  1.0   1.00       1.00   -0.49
# Adj Close  1.00  1.00  1.0   1.00       1.00   -0.49
# Volume    -0.49 -0.48 -0.5  -0.49      -0.49    1.00

# %%
plt.figure(figsize=(13,8))
sns.heatmap(data=df_tm_d_matrix,annot=True)
plt.show()
